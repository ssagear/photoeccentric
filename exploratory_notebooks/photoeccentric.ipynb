# %% [markdown]
# # photoeccentric effect

# %% [markdown]
# paper: https://arxiv.org/pdf/1203.5537.pdf

# %% [markdown]
# 1. Calculate rho_circ (eq. 7)
# 2. Calculate rho_star (eq. 6) (already have from spectroscopy + Gaia)
# 3. Compare them (what is g? g = ratio of rho_star to rho_circ)

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import glob
import csv
plt.rcParams['figure.figsize'] = [10, 5]

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [raw]
# """Saving KICs to csv to upload to Exoplanet Archive"""
#
# rhocsv = np.asarray(list(rho_lum.columns), dtype='int32')
# rhocsv = ['KIC ' + str(i) for i in rhocsv]
# rhocsv = np.array([rhocsv], dtype='str')
#
# # opening the csv file in 'w+' mode
# file = open('KICs.csv', 'w', newline ='')
#
# # writing the data into the file
# with file:
#     write = csv.writer(file)
#     write.writerows(rhocsv)

# %% [markdown]
# #### Start with KIC 10386984.

# %%
rho_lum = pd.read_csv('/Users/sheilasagear/Dropbox (UFL)/Research/MetallicityProject/Code/rhos/rho_lum.csv')

# %%
rho_lum['10386984'].dropna();

# %% [markdown]
# ### NASA Exoplanet archive: https://exoplanetarchive.ipac.caltech.edu/applications/Inventory/search.html
#
# #### Columns explained: https://exoplanetarchive.ipac.caltech.edu/docs/API_exoplanet_columns.html

# %%
#Values are from Exoplanet Archive for KIC 10386984 (1 confirmed transiting planet)

p = 1.287 #days
d = 0.0831 #transit depth
T14 = 1.7642 #hours (1st to 4th contact - full duration (I think?))
ratio = 0.025492 #planet radius/star radius

p_hours = p*24 #period in hours

# %% [markdown]
# ### NASA Exoplanet Archive Transit Service (https://exoplanetarchive.ipac.caltech.edu/cgi-bin/TransitView/nph-visibletbls?dataset=transits)
#
# #### Columns explained: https://exoplanetarchive.ipac.caltech.edu/docs/transit/transit_parameters.html
#
# Downloaded file for KIC 10386984: "/Users/sheilasagear/Dropbox (UFL)/Research/MetallicityProject/Data/exoplanetarchive/transits_2020.10.28_20.34.48.csv"
#
# Ingress JD: 2459151.67707
#
# Egress JD: 2459151.73933

# %%
"""Transit Service lets you search for an upcoming transit
Gives you the start time of ingress and end time of egress"""

ingress_jd1 = 2459152.321
ingress_jd2 = 2459151.67707
egress_jd1 = 2459152.383
egress_jd2 = 2459151.73933

ttime1 = egress_jd1-ingress_jd1 #days
ttime2 = egress_jd2-ingress_jd2 #days

# %%
ttime1 #days
# Out:
# 0.06199999991804361

# %%
ttime1_hours = ttime2*24 #hours

# %% [markdown]
# The Transit & Ephemeris service gives predicted ingress & egress times (JD) and the Expoplanet Archive entry gives transit duration.
#
#
# Why is the end of egress - start of ingress shorter than the total transit duration?

# %%
T14
# Out:
# 1.7642

# %%
ttime1_hours
# Out:
# 1.4942399896681309
