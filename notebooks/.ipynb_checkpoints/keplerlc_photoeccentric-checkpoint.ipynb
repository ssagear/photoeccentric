# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tqdm import tqdm
from astropy.table import Table
import astropy.units as u
import scipy
from scipy import signal


from astropy.io import fits

# Using `batman` to create & fit fake transit
import batman

# Using astropy BLS and scipy curve_fit to fit transit
from astropy.timeseries import BoxLeastSquares
from scipy.optimize import curve_fit

import scipy.optimize as opt

# Using emcee & corner to find and plot (e, w) distribution
import emcee
import corner

# And importing `photoeccentric`
import photoeccentric as ph

# Random stuff
import scipy.constants as c
import os

# %load_ext autoreload
# %autoreload 2

# %matplotlib inline

plt.rcParams['figure.figsize'] = [12, 8]

# %%
nwalk = 64
nsteps_d = 500
ndiscard_d = 100
arrlen = (nsteps_d-ndiscard_d)*nwalk

# %%
smass_kg = 1.9885e30  # Solar mass (kg)
srad_m = 696.34e6 # Solar radius (m)

# %% [markdown]
# ## Reading in Sample Data

# %% [markdown]
# To run with Kepler light curves, determine the stellar mass and radius from any sources. Here I'm compiling a table of the stellar parameters from the NASA exoplanet archive, adding the stellar data from spectroscopy (Muirhead et al. 2013) and luminosities from Gaia, and using ph.fit_isochrone_lum() to fit stellar isochrones to these data. The mass, mass error, radius, and radius error of the fit isochrones will produce my mass + radius distributions which I will use to determine the stellar density distribution.

# %%
muirhead_data = pd.read_csv("datafiles/Muirhead2013_isochrones/muirhead_data_no_missing_data.txt", sep=" ")

# ALL Kepler planets from exo archive
planets = pd.read_csv('datafiles/exoplanetarchive/cumulative_kois.csv')

# Take the Kepler planet archive entries for the planets in Muirhead et al. 2013 sample
spectplanets = planets[planets['kepid'].isin(list(muirhead_data['KIC']))]
spectplanets = spectplanets.reset_index()

# Kepler-Gaia Data
kpgaia = Table.read('datafiles/Kepler-Gaia/kepler_dr2_4arcsec.fits', format='fits').to_pandas();

# Kepler-Gaia data for only the objects in our sample
muirhead_gaia = kpgaia[kpgaia['kepid'].isin(list(muirhead_data.KIC))]
muirhead_gaia = muirhead_gaia.reset_index()
muirhead_gaia.rename(columns={"index": "KIC"})

# Combined spectroscopy data + Gaia/Kepler data for our sample
muirhead_comb = pd.concat([muirhead_data, muirhead_gaia], axis=1)
muirhead_comb_nn = muirhead_comb[muirhead_comb.KOI.notnull()]

# Only targets from table above with published luminosities from Gaia
muirhead_comb_lums = muirhead_comb_nn[muirhead_comb_nn.lum_val.notnull()]

# Read in MESA isochrones
isochrones = pd.read_csv('datafiles/Muirhead2013_isochrones/isochrones_sdss_spitzer_lowmass.dat', sep='\s\s+', engine='python')
# Out:
# /Users/ssagear/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: TableReplaceWarning: converted column 'r_result_flag' from integer to float
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/ssagear/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: TableReplaceWarning: converted column 'r_modality_flag' from integer to float
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/ssagear/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: TableReplaceWarning: converted column 'teff_err1' from integer to float
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/ssagear/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: TableReplaceWarning: converted column 'teff_err2' from integer to float
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %% [markdown]
# ## Outline for Sensitivity Test
#
# 1. Define "test planet" parameters. These parameters will come from a real Kepler planet, but I'll use a fake light curve. These "test planet" parameters will stay the same across the entire test.
# 2. Write two functions: one that wraps the entire light curve initialization process, and one that wraps the transit fit and eccentricity estimation.
# 3. For each eccentricity recovered, take the difference between the input e and the peak of the e distribution as the error.
# 4. Plot on a heatmap

# %% [markdown]
# #### Defining a "test planet"

# %%
# Kepler ID for Kepler-61 b
kepid = 10591855
kepname = spectplanets.loc[spectplanets['kepid'] == kepid].kepler_name.values[0]

kp1367b = muirhead_comb.loc[muirhead_comb['KIC'] == kepid]

# %%
# ph.fit_isochrone_lum() steps through all MESA isochrones and matches the ones that fit the given parameters
#iso_lums = ph.fit_isochrone_lum(kp1367b, muirhead_comb, isochrones, gaia_lum=True)

# Write to csv, then read back in (keeps python notebook from crashing)
#iso_lums.to_csv("datafiles/isochrones/iso_lums_" + str(kepid) + ".csv")

# %%
isodf = pd.read_csv("datafiles/isochrones/iso_lums_" + str(kepid) + ".csv")

mstar = isodf["mstar"].mean()
mstar_err = isodf["mstar"].std()

rstar = isodf["radius"].mean()
rstar_err = isodf["radius"].std()

# %%
rho_star, mass, radius = ph.find_density_dist_symmetric(mstar, mstar_err, rstar, rstar_err, arrlen)

# %%
plt.hist(rho_star, bins=20)
plt.xlabel("Stellar Density [kg m^-3]", fontsize=25)
plt.title("Stellar Density (KIC 10591855) [kg m^-3]", fontsize=20)
# Out:
# Text(0.5, 1.0, 'Stellar Density (KIC 10591855) [kg m^-3]')

# %%
period, period_uerr, period_lerr, rprs, rprs_uerr, rprs_lerr, a_arc, a_uerr_arc, a_lerr_arc, i, e_arc, w_arc = ph.planet_params_from_archive(spectplanets, kepname)

# We calculate a_rs to ensure that it's consistent with the spec/Gaia stellar density.
a_rs = ph.calc_a(period*86400.0, mstar*smass_kg, rstar*srad_m)
a_rs_err = np.mean((a_uerr_arc, a_lerr_arc))

print('Stellar mass (Msun): ', mstar, 'Stellar radius (Rsun): ', rstar)
print('Period (Days): ', period, 'Rp/Rs: ', rprs)
print('a/Rs: ', a_rs)
print('i (deg): ', i)
# Out:
# Stellar mass (Msun):  0.6225761982225098 Stellar radius (Rsun):  0.6040319320536421
# Period (Days):  1.574090323 Rp/Rs:  0.013129
# a/Rs:  8.042709544727982
# i (deg):  89.48

# %% [markdown]
# ##### Calculate A_rs prior:

# %%
pdist = np.random.normal(period, np.mean((abs(period_uerr), abs(period_lerr))), len(rho_star))

a_rs_gaia = ph.get_a_rs(rho_star, pdist)
a_rs_gaia_sigmin, a_rs_gaia_sigpls = ph.get_sigmas(a_rs_gaia)

a_rs_guess = np.mean(a_rs_gaia)

#a/Rs priors to put in transit fitting
a_rs_priors = [a_rs_guess-10*np.std(a_rs_gaia), a_rs_guess+10*np.std(a_rs_gaia)]

# %% [markdown]
# # Using photo_init and photo_fit

# %%
hdu = fits.open('datafiles/MAST_2021-04-27T1542/Kepler/kplr006960913_lc_Q011111111111111111/kplr006960913-2009259160929_llc.fits')
time = hdu[1].data['TIME'] + hdu[1].header['BJDREFI']
flux_u = hdu[1].data['PDCSAP_FLUX']
flux_err_u = hdu[1].data['PDCSAP_FLUX_ERR']

# %%
def normalize_flux(flux_u, flux_err_u):
    """Normalizes flux array."""

    fmed = np.nanmedian(flux_u)
    flux = flux_u/fmed
    flux_err = flux_err_u/fmed
    
    return flux, flux_err

# %%
flux, flux_err = normalize_flux(flux_u, flux_err_u)

# %%
t0 = 2454984.188
tm1 = 2454984.188+59.87756*100
tmidtimes = np.arange(t0, tm1, 59.87756)

# %%
midjd = np.genfromtxt('datafiles/keplerstellar/kep61-mpts.csv', delimiter=',')[1:]

# %%
cmtimes = []
for j in range(len(midjd)):
    if time[0] < midjd[j] < time[-1]:
        cmtimes.append(midjd[j])

# %%
transitmid = cmtimes[0]

# %%
#nanind = np.argwhere(np.isnan(flux) | np.isnan(time))

#time = np.delete(time, nanind)
#flux = np.delete(flux, nanind)
#flux_err = np.delete(flux_err, nanind)

# %%
start = hdu[1].header['TSTART'] + hdu[1].header['BJDREFI']
end = hdu[1].header['TSTOP'] + hdu[1].header['BJDREFI']

# %%
def get_mid(time):
    """Gets approximately 1/2 of cadence time."""
    
    return (time[1]-time[0])/2.

# %%
mid = get_mid(time)

# %%
def find_nearest(array, value):
    array = np.asarray(array)
    idx = np.nanargmin((np.abs(array - value)))
    return array[idx]

# %%
def get_transit_cutout(transitmid, ncadences, time, flux, flux_err):
    
    """Gets cutout with n cadences before and after transit.
    transitmid and time have same units.
    
    Parameters
    ----------
    transitmid: float
        Transit mid-time
    ncadences: int
        Number of cadences before and after transit mid-time.
    time: np.array
        Time 
    flux: np.array
        Flux
        
    Returns
    -------
    t1: np.array
        Cutout time
    f1: np.array
        Cutout flux
    fe1: np.array
        Cutout flux error
    
    """
    
    
    tindex = int(np.where(time == find_nearest(time, transitmid))[0])

    n = 20

    t1 = time[tindex-n:tindex+n] - transitmid
    f1 = flux[tindex-n:tindex+n]
    fe1 = flux_err[tindex-n:tindex+n]
    
    return t1, f1, fe1

# %%
plt.scatter(time, flux)
plt.axvline(transitmid, c='r')
plt.ylim(.990, 1.010)
# Out:
# (0.99, 1.01)

# %%
#f1 = f1/np.nanmean(f1)

# %%
plt.errorbar(t1, f1, yerr=fe1)
#plt.axvline(0, c='r')
#plt.ylim(8900, 9000)
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
idx = np.isfinite(t1) & np.isfinite(f1)

disc = 15

m, b = np.polyfit(np.concatenate((t1[idx][:disc], t1[idx][-disc:])), np.concatenate((f1[idx][:disc], f1[idx][-disc:])), 1)

# %%
plt.plot(t1, m*t1 + b, c='g')
plt.scatter(t1, f1)
plt.axvline(0, c='r')

# %%
linfit = m*t1 + b

# %%
#fnorm = (f1-linfit)+1
fnorm = (f1-linfit)+1

# %%
plt.scatter(t1, fnorm)
plt.axvline(0, c='r')
#plt.ylim(-20, 20)

# %%
def divide_chunks(l, n):
    for i in range(0, len(l), n):
        yield l[i:i + n]
        

def array_integrated(arr, nint):

    arr = list(divide_chunks(arr, nint))
    arr = np.mean(np.array(arr), axis=1)

    return arr

# %%
def get_ptime(time, mid, num):

    eti = []

    for i in range(len(time)):
        ettemp = np.linspace(time[i]-mid, time[i]+mid, num, endpoint=True)
        ettemp = list(ettemp)

        eti.append(ettemp)
        
    ptime = np.array([item for sublist in eti for item in sublist])
    
    return ptime

# %%
ptime = get_ptime(t1, mid, 29)

# %%
len(ptime)/29. == len(t1)
# Out:
# True

# %%
# initialize arrays w zeros

n = 1

gmeans = np.zeros(n)
gsigs = np.zeros(n)
es_best = np.zeros(n)
ws_best = np.zeros(n)
zscores = np.zeros((n, 2))

# %% [markdown]
# This cell measures (e,w) for n synthetic transits. All transits assume the exact same system (both stellar and planet parameters), except for e and w. Here I am simulating Kepler-1582b over and over with different (e,w) each time, and seeing if photoeccentric recovers the correct values.
#
# `zscores` is a list of length 2. Index 0 is the zscore of the fit eccentricity compared to the true eccentricity. Index 1 is the zscore of the fit w compared to the true w. This isn't a good way to do this but ehhh idk yet
#
# `direct` needs to be set as the directory where you want plots to be saved

# %%
#blsper = ph.bls(t1, fnorm)

# %%
#blsper

# %%
fnorm = np.nan_to_num(fnorm, nan=1.0)
fe1 = np.nan_to_num(fe1, nan=1.0)

# %%
# print('Period (Days): ', period)
# print('Rp/Rs: ', rprs)
# print('a/Rs: ', a_rs)
# print('i (deg): ', i)

dr = 'RealKeplerLC_Kp61'
direct = 'plots/' + dr + '/'

if not os.path.exists(direct):
    os.mkdir(direct)

# nsteps kept 1000, nwalkers 32, len(result) 32000

guess_transit = np.array([59, 0.03301, 90.6, 89.9])
guess_ew = np.array([0, 0])

beste, bestw, edist, wdist, gs, g_mean, g_sigmas, zsc = ph.photo_fit(t1, ptime, fnorm, fe1, guess_transit, guess_ew, rho_star, 0.0, 0.0, direct, nwalk, nsteps_d, ndiscard_d) 
gmeans = g_mean
gsigs = np.mean(g_sigmas)
es_best = beste
ws_best = bestw
zscores = np.mean(zsc)
print("Best e: ", beste)


p_f, perr_f = np.mean(pdist), ph.get_sigmas(pdist)
rprs_f, rprserr_f = np.mean(rdist), ph.get_sigmas(rdist)
a_f, aerr_f = np.mean(adist), ph.get_sigmas(adist)
i_f, ierr_f = np.mean(idist), ph.get_sigmas(idist)
# Out:
# 100%|██████████| 500/500 [00:40<00:00, 12.24it/s]
# Fit params:
# Period (days):  83.7959867048966
# Rp/Rs:  0.03476590176980304
# a/Rs:  102.00092711877478
# i (deg):  89.6686680559973
# /Users/ssagear/Dropbox (UFL)/Research/MetallicityProject/photoeccentric/photoeccentric/photoeccentric.py:137: RuntimeWarning: invalid value encountered in sqrt
#   T23[j] = (p[j]/np.pi)*np.arcsin(rs_a[j]*(np.sqrt(((1-rprs[j])**2)-b[j]**2))/np.sin(i[j]*(np.pi/180.0))) #Equation 14 in exoplanet textbook
#   0%|          | 0/5000 [00:00<?, ?it/s]/Users/ssagear/anaconda3/lib/python3.8/site-packages/emcee/moves/red_blue.py:99: RuntimeWarning: invalid value encountered in double_scalars
#   lnpdiff = f + nlp - state.log_prob[j]
#   5%|▍         | 231/5000 [00:00<00:04, 1134.49it/s]
# -------MCMC------
# 100%|██████████| 5000/5000 [00:04<00:00, 1189.61it/s]
# Best e:  0.26494243590239763
# ---------------------------------------------------------------------------
# ...

# %%
# Create a light curve with the fit parameters

#mcmcfit = integrate_lcfitter(t1, rprs_f, a_f, i_f)
mcmcfit = integrate_lcfitter(t1, 0.03426683260779337, 97.74330018188869, 89.66875192078044)

plt.errorbar(t1, fnorm, yerr=fe1, c='blue', alpha=0.5, label='Original LC', fmt="o", capsize=0)
plt.scatter(t1, mcmcfit, c='red', alpha=1.0, label='Fit LC')
plt.plot(t1, mcmcfit, c='red', alpha=1.0)

plt.legend()

# %% [markdown]
# #### Defining a "test planet"

# %%
# Kepler ID for Kepler-1582 b
kepid = 5868793
kepname = spectplanets.loc[spectplanets['kepid'] == kepid].kepler_name.values[0]

kp1367b = muirhead_comb.loc[muirhead_comb['KIC'] == kepid]

# %%
# ph.fit_isochrone_lum() steps through all MESA isochrones and matches the ones that fit the given parameters
#iso_lums = ph.fit_isochrone_lum(kp1367b, muirhead_comb, isochrones, gaia_lum=True)

# Write to csv, then read back in (keeps python notebook from crashing)
#iso_lums.to_csv("datafiles/isochrones/iso_lums_" + str(kepid) + ".csv")

# %%
isodf = pd.read_csv("datafiles/isochrones/iso_lums_" + str(kepid) + ".csv")

mstar = isodf["mstar"].mean()
mstar_err = isodf["mstar"].std()

rstar = isodf["radius"].mean()
rstar_err = isodf["radius"].std()

# %%
rho_star, mass, radius = ph.find_density_dist_symmetric(mstar, mstar_err, rstar, rstar_err, arrlen)

# %%
plt.hist(rho_star, bins=20)
plt.xlabel("Stellar Density [kg m^-3]", fontsize=25)
plt.title("Stellar Density (KIC 5868793) [kg m^-3]", fontsize=20)

# %%
period, period_uerr, period_lerr, rprs, rprs_uerr, rprs_lerr, a_arc, a_uerr_arc, a_lerr_arc, i, e_arc, w_arc = ph.planet_params_from_archive(spectplanets, kepname)

# We calculate a_rs to ensure that it's consistent with the spec/Gaia stellar density.
a_rs = ph.calc_a(period*86400.0, mstar*smass_kg, rstar*srad_m)
a_rs_err = np.mean((a_uerr_arc, a_lerr_arc))

print('Stellar mass (Msun): ', mstar, 'Stellar radius (Rsun): ', rstar)
print('Period (Days): ', period, 'Rp/Rs: ', rprs)
print('a/Rs: ', a_rs)
print('i (deg): ', i)

# %% [markdown]
# ##### Calculate A_rs prior:

# %%
pdist = np.random.normal(period, np.mean((abs(period_uerr), abs(period_lerr))), len(rho_star))

a_rs_gaia = ph.get_a_rs(rho_star, pdist)
a_rs_gaia_sigmin, a_rs_gaia_sigpls = ph.get_sigmas(a_rs_gaia)

a_rs_guess = np.mean(a_rs_gaia)

#a/Rs priors to put in transit fitting
a_rs_priors = [a_rs_guess-10*np.std(a_rs_gaia), a_rs_guess+10*np.std(a_rs_gaia)]

# %% [markdown]
# # Using photo_init and photo_fit

# %%
#hdu = fits.open('/Users/sheilasagear/Dropbox (UFL)/Research/MetallicityProject/photoeccentric/notebooks/datafiles/MAST_2021-04-23T1345/Kepler/kplr010591855_lc_Q011111111111111111/kplr010591855-2011073133259_llc.fits')
hdu = fits.open('datafiles/MAST_2021-04-27T1542/Kepler/kplr006960913_lc_Q011111111111111111/kplr006960913-2010265121752_llc.fits')
time = hdu[1].data['TIME'] + hdu[1].header['BJDREFI']
flux = hdu[1].data['PDCSAP_FLUX']
flux_err = hdu[1].data['PDCSAP_FLUX_ERR']

# %%
fmed = np.nanmedian(flux)

flux = flux/fmed
flux_err = flux_err/fmed

# %%
t0 = hdu[1].header['BJDREFI']
tm1 = hdu[1].header['BJDREFI']+period*100
tmidtimes = np.arange(t0, tm1, period)

# %%
midjd = np.genfromtxt('datafiles/keplerstellar/kep61-mpts.csv', delimiter=',')[1:]

# %%
cmtimes = []
for j in range(len(midjd)):
    if time[0] < midjd[j] < time[-1]:
        cmtimes.append(midjd[j])

# %%
transitmid = cmtimes[0]

# %%
#nanind = np.argwhere(np.isnan(flux) | np.isnan(time))

#time = np.delete(time, nanind)
#flux = np.delete(flux, nanind)
#flux_err = np.delete(flux_err, nanind)

# %%
start = hdu[1].header['TSTART'] + hdu[1].header['BJDREFI']
end = hdu[1].header['TSTOP'] + hdu[1].header['BJDREFI']

# %%
mid = (time[1]-time[0])/2.

# %%
mid
# Out:
# 0.010217133909463882

# %%
def find_nearest(array, value):
    array = np.asarray(array)
    idx = np.nanargmin((np.abs(array - value)))
    return array[idx]

# %%
tindex = int(np.where(time == find_nearest(time, transitmid))[0])
print(tindex)

n = 20

t1 = time[tindex-n:tindex+n] - transitmid
f1 = flux[tindex-n:tindex+n]
fe1 = flux_err[tindex-n:tindex+n]
# Out:
# 2033

# %%
time
# Out:
# array([2455002.52015042, 2455002.54058468, 2455002.56101895, ...,
#        2455091.42702699, 2455091.44746002, 2455091.46789314])

# %%
plt.scatter(time, flux)
plt.axvline(transitmid, c='r')
plt.ylim(.990, 1.010)
# Out:
# (0.99, 1.01)

# %%
#f1 = f1/np.nanmean(f1)

# %%
plt.errorbar(t1, f1, yerr=fe1)
#plt.axvline(0, c='r')
#plt.ylim(8900, 9000)
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
idx = np.isfinite(t1) & np.isfinite(f1)

disc = 15

m, b = np.polyfit(np.concatenate((t1[idx][:disc], t1[idx][-disc:])), np.concatenate((f1[idx][:disc], f1[idx][-disc:])), 1)

# %%
plt.plot(t1, m*t1 + b, c='g')
plt.scatter(t1, f1)
plt.axvline(0, c='r')

# %%
linfit = m*t1 + b

# %%
#fnorm = (f1-linfit)+1
fnorm = (f1-linfit)+1

# %%
plt.scatter(t1, fnorm)
plt.axvline(0, c='r')
#plt.ylim(-20, 20)

# %%
def divide_chunks(l, n):
    for i in range(0, len(l), n):
        yield l[i:i + n]
        

def array_integrated(arr, nint):

    arr = list(divide_chunks(arr, nint))
    arr = np.mean(np.array(arr), axis=1)

    return arr

# %%
def get_ptime(time, mid, num):

    eti = []

    for i in range(len(time)):
        ettemp = np.linspace(time[i]-mid, time[i]+mid, num, endpoint=True)
        ettemp = list(ettemp)

        eti.append(ettemp)
        
    ptime = np.array([item for sublist in eti for item in sublist])
    
    return ptime

# %%
ptime = get_ptime(t1, mid, 29)

# %%
len(ptime)/29. == len(t1)
# Out:
# True

# %%
# initialize arrays w zeros

n = 1

gmeans = np.zeros(n)
gsigs = np.zeros(n)
es_best = np.zeros(n)
ws_best = np.zeros(n)
zscores = np.zeros((n, 2))

# %% [markdown]
# This cell measures (e,w) for n synthetic transits. All transits assume the exact same system (both stellar and planet parameters), except for e and w. Here I am simulating Kepler-1582b over and over with different (e,w) each time, and seeing if photoeccentric recovers the correct values.
#
# `zscores` is a list of length 2. Index 0 is the zscore of the fit eccentricity compared to the true eccentricity. Index 1 is the zscore of the fit w compared to the true w. This isn't a good way to do this but ehhh idk yet
#
# `direct` needs to be set as the directory where you want plots to be saved

# %%
#blsper = ph.bls(t1, fnorm)

# %%
#blsper

# %%
fnorm = np.nan_to_num(fnorm, nan=1.0)
fe1 = np.nan_to_num(fe1, nan=1.0)

# %%
# print('Period (Days): ', period)
# print('Rp/Rs: ', rprs)
# print('a/Rs: ', a_rs)
# print('i (deg): ', i)

dr = 'RealKeplerLC_Kp61'
direct = 'plots/' + dr + '/'

if not os.path.exists(direct):
    os.mkdir(direct)

# nsteps kept 1000, nwalkers 32, len(result) 32000

guess_transit = np.array([59, 0.03301, 90.6, 89.9])
guess_ew = np.array([0, 0])

beste, bestw, edist, wdist, gs, g_mean, g_sigmas, zsc = ph.photo_fit(t1, ptime, fnorm, fe1, guess_transit, guess_ew, rho_star, 0.0, 0.0, direct, nwalk, nsteps_d, ndiscard_d) 
gmeans = g_mean
gsigs = np.mean(g_sigmas)
es_best = beste
ws_best = bestw
zscores = np.mean(zsc)
print("Best e: ", beste)


p_f, perr_f = np.mean(pdist), ph.get_sigmas(pdist)
rprs_f, rprserr_f = np.mean(rdist), ph.get_sigmas(rdist)
a_f, aerr_f = np.mean(adist), ph.get_sigmas(adist)
i_f, ierr_f = np.mean(idist), ph.get_sigmas(idist)
# Out:
# 100%|██████████| 500/500 [01:07<00:00,  7.43it/s]
# Fit params:
# Period (days):  79.31497938610298
# Rp/Rs:  0.03426683260779337
# a/Rs:  97.74330018188869
# i (deg):  89.66875192078044
# /Users/sheilasagear/Dropbox (UFL)/Research/MetallicityProject/photoeccentric/photoeccentric/photoeccentric.py:137: RuntimeWarning: invalid value encountered in sqrt
#   T23[j] = (p[j]/np.pi)*np.arcsin(rs_a[j]*(np.sqrt(((1-rprs[j])**2)-b[j]**2))/np.sin(i[j]*(np.pi/180.0))) #Equation 14 in exoplanet textbook
#   0%|          | 0/5000 [00:00<?, ?it/s]/Users/sheilasagear/opt/anaconda3/lib/python3.7/site-packages/emcee/moves/red_blue.py:99: RuntimeWarning: invalid value encountered in double_scalars
#   lnpdiff = f + nlp - state.log_prob[j]
#   1%|          | 58/5000 [00:00<00:08, 577.49it/s]
# -------MCMC------
# 100%|██████████| 5000/5000 [00:05<00:00, 837.31it/s]
# Best e:  0.2874977040498065

# %%
# Create a light curve with the fit parameters

#mcmcfit = integrate_lcfitter(t1, rprs_f, a_f, i_f)
mcmcfit = integrate_lcfitter(t1, 0.03426683260779337, 97.74330018188869, 89.66875192078044)

plt.errorbar(t1, fnorm, yerr=fe1, c='blue', alpha=0.5, label='Original LC', fmt="o", capsize=0)
plt.scatter(t1, mcmcfit, c='red', alpha=1.0, label='Fit LC')
plt.plot(t1, mcmcfit, c='red', alpha=1.0)

plt.legend()

# %% [markdown]
# # Start over omg

# %% [markdown]
# https://emcee.readthedocs.io/en/stable/tutorials/line/

# %%
import batman

# %%
def integrate_lcfitter(time, rp, ars, inc):
    
    params = batman.TransitParams()       #object to store transit parameters
    params.t0 = 0                        #time of inferior conjunction
    params.per = 59.0                      #orbital period
    params.rp = rp                        #planet radius (in units of stellar radii)
    params.a = ars                          #semi-major axis (in units of stellar radii)
    params.inc = inc                      #orbital inclination (in degrees)
    params.ecc = 0.0                      #eccentricity
    params.w = 0.0                       #longitude of periastron (in degrees)
    #params.limb_dark = "linear"
    #params.u = [0.3]
    params.limb_dark = "quadratic"
    params.u = [0.5, 0.2]
    #params.limb_dark = "uniform"
    #params.u = []

    #times to calculate light curve
    ptime = get_ptime(time, 0.010217133909463882, 29)
    
    m = batman.TransitModel(params, ptime)
    
    pflux = m.light_curve(params)
    flux = array_integrated(pflux, 29)
    
    return flux

# %%
soln = [0.03301, 90.6, 89.9] # r, ars, i

# %%
def log_likelihood(theta, time, flux, fluxerr):
    rp, ars, inc = theta
    model = integrate_lcfitter(time, rp, ars, inc)
    sigma2 = fluxerr ** 2
    return -0.5 * np.sum((flux - model) ** 2 / sigma2 + np.log(sigma2))

# %%
def log_prior(theta):
    rp, ars, inc = theta
    if 0.0 < rp < 1.0 and 0.0 < ars < 200.0 and 0.0 < inc < 90.0:
        return 0.0
    return -np.inf

# %%
def log_probability(theta, time, flux, fluxerr):
    lp = log_prior(theta)
    if not np.isfinite(lp):
        return -np.inf
    return lp + log_likelihood(theta, time, flux, fluxerr)

# %%
pos = soln + 1e-4 * np.random.randn(32, 3)
nwalkers, ndim = pos.shape

sampler = emcee.EnsembleSampler(nwalkers, ndim, log_probability, args=(t1, fnorm, fe1))
sampler.run_mcmc(pos, 5000, progress=True);
# Out:
# 100%|██████████| 5000/5000 [05:35<00:00, 14.90it/s]

# %%
fig, axes = plt.subplots(3, figsize=(10, 7), sharex=True)
samples = sampler.get_chain()
labels = ["r", "a", "i"]
for i in range(ndim):
    ax = axes[i]
    ax.plot(samples[:, :, i], "k", alpha=0.3)
    ax.set_xlim(0, len(samples))
    ax.set_ylabel(labels[i])
    ax.yaxis.set_label_coords(-0.1, 0.5)

axes[-1].set_xlabel("step number");

# %%
flat_samples = sampler.get_chain(discard=100, thin=15, flat=True)

# %%
flat_samples[:1]
# Out:
# array([[3.42413410e-02, 8.96678995e+01, 8.99704641e+01]])

# %%
rprsf = np.nanmean(flat_samples[:,0])
af = np.mean(flat_samples[:,1])
incf = np.mean(flat_samples[:,2])

# %%
print(rprsf, af, incf)
# Out:
# 0.03497637582580567 71.48265626404638 89.54095494597688

# %%
# Create a light curve with the fit parameters

mcmcfit = integrate_lcfitter(t1, rprsf, af, incf)

plt.errorbar(t1, fnorm, yerr=fe1, c='blue', alpha=0.5, label='Original LC', fmt="o", capsize=0)
plt.scatter(t1, mcmcfit, c='red', alpha=1.0, label='Fit LC')
plt.plot(t1, mcmcfit, c='red', alpha=1.0)

plt.legend()

# %% [markdown]
# # Scipy lsq

# %%
# Create a light curve with the fit parameters
fit1 = array_integrated(ph.planetlc_fitter(ptime, rprs_f, a_f, i_f, 0.0), 29)
#fit = ph.planetlc_fitter(ptime, rprs_f, a_f, i_f, 0.0)
#fit2 = array_integrated(ph.planetlc_fitter(ptime, 0.03301, 90.6, 89.9, 0.0), 29)


plt.cla()
plt.scatter(t1, fnorm, c='blue', alpha=0.5, label='Original LC')
#plt.plot(ptime, fit, c='red', alpha=1.0, label='Fit LC')
#plt.scatter(t1, fit2, c='purple', alpha=1.0, label='Real Fit LC')
plt.scatter(t1, fit1, c='red', alpha=1.0, label='Real Fit LC')
#plt.xlim(-0.1, 0.1)
plt.legend()


print('Fit params:')
print('Rp/Rs: ', rprs_f)
print('a/Rs: ', a_f)
print('i (deg): ', i_f)
# Out:
# Fit params:
# Rp/Rs:  0.051272782271003035
# a/Rs:  98.19664680859464
# i (deg):  88.58088334683785

# %%
from scipy.optimize import leastsq

# %%
def plcf(time, theta):
    ptime = get_ptime(t1, mid, 29)
    return ph.array_integrated(ph.planetlc_fitter(ptime, theta[0], theta[1], theta[2], 0.0), 29)

# %%
def residuals(coeffs, y, t):
    return y - plcf(t, coeffs)

# %%
x0 = np.array([0.03301, 90.6, 89.9], dtype=float)

# %%
x, flag = leastsq(residuals, x0, args=(fnorm, t1))

# %%
rprs_f = x[0]
a_f = x[1]
i_f = x[2]

# %%
# Create a light curve with the fit parameters
fit1 = array_integrated(ph.planetlc_fitter(ptime, rprs_f, a_f, i_f, 0.0), 29)
#fit = ph.planetlc_fitter(ptime, rprs_f, a_f, i_f, 0.0)
fit2 = array_integrated(ph.planetlc_fitter(ptime, 0.03301, 90.6, 89.9, 0.0), 29)


plt.cla()
plt.scatter(t1, fnorm, c='blue', alpha=0.5, label='Original LC')
#plt.plot(ptime, fit, c='red', alpha=1.0, label='Fit LC')
#plt.scatter(t1, fit2, c='purple', alpha=1.0, label='Real Fit LC')
plt.scatter(t1, fit1, c='red', alpha=1.0, label='Real Fit LC')
#plt.xlim(-0.1, 0.1)
plt.legend()

# %%
x
# Out:
# array([3.52594858e-02, 6.78751883e+01, 8.94709947e+01])

# %%
import mc3

# %%
# Modeling function:
func = plcf
# List of additional arguments of func (if necessary):
indparams = [ptime]

# Array of initial-guess values of fitting parameters:
params = np.array([0.03301, 90.6, 89.9])
# Lower and upper boundaries for the MCMC exploration:
pmin = np.array([0.0, 0.0, 0.0])
pmax = np.array([ 1.0,  200.0,  90.0])
# Parameters' stepping behavior:
pstep = np.array([0.001, 0.1, 0.1])

# Two-sided Gaussian prior on first parameter, uniform priors on rest:
prior    = np.array([0.0, 0.0, 0.0])
priorlow = np.array([0.0, 0.0, 0.0])
priorup  = np.array([0.0, 0.0, 0.0])

# Parameter names:
pnames   = ['rprs', 'ars', 'i']
texnames = [r'rprs', r'ars', r'i']

# Sampler algorithm, choose from: 'snooker', 'demc', 'mrw', or 'dynesty'.
sampler = 'dynesty'

# Optimization before MCMC, choose from: 'lm' or 'trf':
leastsq    = 'lm'
chisqscale = False
# NS setup:
ncpu     = 7
thinning = 1

# Logging:
log = 'NS_tutorial.log'

# File outputs:
savefile = 'NS_tutorial.npz'
plots    = True
rms      = True

# Run the MCMC:
mc3_output = mc3.sample(data=fnorm, uncert=fe1, func=func, params=params,
     indparams=indparams, pmin=pmin, pmax=pmax, pstep=pstep,
     pnames=pnames, texnames=texnames,
     prior=prior, priorlow=priorlow, priorup=priorup,
     sampler=sampler, ncpu=ncpu, thinning=thinning,
     leastsq=leastsq, chisqscale=chisqscale,
     plots=plots, rms=rms, log=log, savefile=savefile)
# Out:
# ::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::
#   Multi-core Markov-chain Monte Carlo (mc3).
#   Version 3.0.8.
#   Copyright (c) 2015-2021 Patricio Cubillos and collaborators.
#   mc3 is open-source software under the MIT license (see LICENSE).
# ::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::
#
#
# ::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::
# ...
#     The number of requested CPUs (7) is >= than the number of
# available CPUs (4).  Enforced ncpu to 3.
# ::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::
#
# Least-squares best-fitting parameters:
#   [3.301e-02 9.060e+01 8.990e+01]
#
# Running dynesty dynamic nested-samping run:
# 649it [03:03,  3.53it/s, batch: 0 | bound: 10 | nc: 97 | ncall: 316721 | eff(%):  0.205 | loglstar:   -inf < -0.000 <    inf | logz: -0.327 +/-  0.036 | dlogz:  0.322 >  0.010] Process ForkPoolWorker-2:
# Process ForkPoolWorker-3:
# Process ForkPoolWorker-1:
# ...

# %%
fe1
# Out:
# array([4.4178605, 4.4182873, 4.4177227, 4.4179606, 4.4190564, 4.419072 ,
#        4.41876  , 4.418409 , 4.419674 , 4.4184885, 4.419599 , 4.4180336,
#        4.418322 , 4.4188495, 4.41827  , 4.417881 , 4.4171414, 4.417195 ,
#        4.4165998, 4.4167943, 4.416544 , 4.415842 , 4.4173284, 4.4164796,
#        4.416676 , 4.417872 , 4.4176836, 4.418128 , 4.418136 , 4.417469 ,
#        4.4177594, 4.4173098, 4.418082 , 4.417917 , 4.4179125, 4.417686 ,
#        4.418311 , 4.4180436, 4.4177814, 4.4187894], dtype=float32)
