# %% [markdown]
# # fitting real Kepler light curves

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tqdm import tqdm
from astropy.table import Table
import astropy.units as u
import scipy
from scipy import signal


from astropy.io import fits

# Using astropy BLS and scipy curve_fit to fit transit
from astropy.timeseries import BoxLeastSquares
from scipy.optimize import curve_fit

import scipy.optimize as opt

# Using emcee & corner to find and plot (e, w) distribution
import emcee
import corner

# And importing `photoeccentric`
import photoeccentric as ph

# Random stuff
import scipy.constants as c
import os

# %load_ext autoreload
# %autoreload 2

# %matplotlib inline

plt.rcParams['figure.figsize'] = [12, 8]

# %%
nwalk = 64
nsteps_d = 1500
ndiscard_d = 1000
arrlen = (nsteps_d-ndiscard_d)*nwalk

# %%
smass_kg = 1.9885e30  # Solar mass (kg)
srad_m = 696.34e6 # Solar radius (m)

# %% [markdown]
# ## Reading in Sample Data

# %%
spectplanets = pd.read_csv('spectplanets.csv')
muirhead_comb = pd.read_csv('muirhead_comb.csv')
muirhead_comb_lums = pd.read_csv('muirhead_comb_lums.csv')
muirhead_lamost = pd.read_csv('muirhead_lamost.csv')

# %%
KICs = np.sort(np.unique(np.array(muirhead_comb['KIC'])))
KOIs = np.sort(np.unique(np.array(muirhead_comb['KOI'])))

# %%
KOIs
# Out:
# array(['1078', '1085', '1141', '1146', '1201', '1393', '1397', '1408',
#        '1422', '1427', '1459', '1649', '1681', '1686', '1702', '1725A',
#        '1725B', '1843', '1867', '1868', '1879', '1880', '1902', '1907',
#        '2006', '2036', '2057', '2058', '2090', '2130', '2156', '2179',
#        '2191', '2238', '2306', '2329', '2347', '2417', '2418', '2453',
#        '247', '248', '249A', '249B', '250', '251', '252', '253', '254',
#        '2542', '255', '256', '2626', '2650', '2662', '2704', '2705',
#        '2715', '2764', '2839', '2842', '2845', '2862', '2926', '2992',
#        '3010', '3034', '3090', '3119', '314', '3140', '3144', '3263',
#        '3282', '3284', '3414', '3444', '3497', '3749', '4087', '4252',
#        '4290', '4427', '4463SE', '463', '478', '4875', '531', '571',
#        '596', '641', '739', '781', '812', '817', '818', '854', '886',
#        '898', '899', '936', '947', '952', '961', '977'], dtype=object)

# %%
strkois = [str(i) for i in KOIs]

# %%
strkois = ['KOI ' + i for i in strkois]

# %%
# Some of these are false positives, e.g. KOI 961

# KOIs

# %%
#np.savetxt('MuirheadKOIs.txt', strkois, fmt='%s')

# %%
lcpath = '/Users/ssagear/Dropbox (UFL)/Research/MetallicityProject/photoeccentric/notebooks/datafiles/sample_LCs/'
lclist = []

for i in range(len(KICs)):
    templst = []
    for subdir, dirs, files in os.walk(lcpath):
        for file in files:
            if str(KICs[i]) in file:
                templst.append(os.path.join(subdir, file))
    lclist.append(templst)

# %%
def get_stitched_lcs(KOI):
    
    files = lclist[int(np.argwhere(KOIs==KOI))]

    files = sorted(files)
    
    time = []
    flux = []
    flux_err = []
    hdus = []
    
    for file in files[0:1]:
        hdu = fits.open(file)
        time_p = list(hdu[1].data['TIME'] + hdu[1].header['BJDREFI'])
        time.append(time_p)
        flux_p = hdu[1].data['PDCSAP_FLUX']
        flux_err_p = hdu[1].data['PDCSAP_FLUX_ERR']
        
        fmed = np.nanmedian(flux_p)
        
        print(hdu[1].header['TSTART'] + hdu[1].header['BJDREFI'], time_p[0])
        print(hdu[1].header['DATE-OBS'])
        
        flux.append(list(flux_p/fmed))
        flux_err.append(list(flux_err_p/fmed))
        
        hdus.append(hdu)


        #hdu.close()
    
    return hdus, time, flux, flux_err

# %%
hdus, t, f, fe = get_stitched_lcs('4290')
hdus[0][1].header
# Out:
# 2454964.50212929 2454964.51234641
# XTENSION= 'BINTABLE'           / marks the beginning of a new HDU
# BITPIX  =                    8 / array data type
# NAXIS   =                    2 / number of array dimensions
# NAXIS1  =                  100 / length of first array dimension
# NAXIS2  =                 1639 / length of second array dimension
# PCOUNT  =                    0 / group parameter count (not used)
# GCOUNT  =                    1 / group count (not used)
# TFIELDS =                   20 / number of table fields
# TTYPE1  = 'TIME    '           / column title: data time stamps
# TFORM1  = 'D       '           / column format: 64-bit floating point
# TUNIT1  = 'BJD - 2454833'      / column units: barycenter corrected JD
# TDISP1  = 'D14.7   '           / column display format
# TTYPE2  = 'TIMECORR'           / column title: barycenter - timeslice correction
# TFORM2  = 'E       '           / column format: 32-bit floating point
# TUNIT2  = 'd       '           / column units: day
# TDISP2  = 'E13.6   '           / column display format
# TTYPE3  = 'CADENCENO'          / column title: unique cadence number
# TFORM3  = 'J       '           / column format: signed 32-bit integer
# TDISP3  = 'I10     '           / column display format
# TTYPE4  = 'SAP_FLUX'           / column title: aperture photometry flux
# TFORM4  = 'E       '           / column format: 32-bit floating point
# TUNIT4  = 'e-/s    '           / column units: electrons per second
# TDISP4  = 'E14.7   '           / column display format
# TTYPE5  = 'SAP_FLUX_ERR'       / column title: aperture phot. flux error
# TFORM5  = 'E       '           / column format: 32-bit floating point
# TUNIT5  = 'e-/s    '           / column units: electrons per second (1-sigma)
# TDISP5  = 'E14.7   '           / column display format
# TTYPE6  = 'SAP_BKG '           / column title: aperture phot. background flux
# TFORM6  = 'E       '           / column format: 32-bit floating point
# TUNIT6  = 'e-/s    '           / column units: electrons per second
# TDISP6  = 'E14.7   '           / column display format
# TTYPE7  = 'SAP_BKG_ERR'        / column title: ap. phot. background flux error
# TFORM7  = 'E       '           / column format: 32-bit floating point
# TUNIT7  = 'e-/s    '           / column units: electrons per second (1-sigma)
# TDISP7  = 'E14.7   '           / column display format
# TTYPE8  = 'PDCSAP_FLUX'        / column title: aperture phot. PDC flux
# TFORM8  = 'E       '           / column format: 32-bit floating point
# TUNIT8  = 'e-/s    '           / column units: electrons per second
# TDISP8  = 'E14.7   '           / column display format
# TTYPE9  = 'PDCSAP_FLUX_ERR'    / column title: ap. phot. PDC flux error
# TFORM9  = 'E       '           / column format: 32-bit floating point
# TUNIT9  = 'e-/s    '           / column units: electrons per second (1-sigma)
# TDISP9  = 'E14.7   '           / column display format
# TTYPE10 = 'SAP_QUALITY'        / column title: aperture photometry quality flag
# TFORM10 = 'J       '           / column format: signed 32-bit integer
# TDISP10 = 'B16.16  '           / column display format
# TTYPE11 = 'PSF_CENTR1'         / column title: PSF-fitted column centroid
# TFORM11 = 'D       '           / column format: 64-bit floating point
# TUNIT11 = 'pixel   '           / column units: pixel
# TDISP11 = 'F10.5   '           / column display format
# TTYPE12 = 'PSF_CENTR1_ERR'     / column title: PSF-fitted column error
# TFORM12 = 'E       '           / column format: 32-bit floating point
# TUNIT12 = 'pixel   '           / column units: pixel (1-sigma)
# TDISP12 = 'E14.7   '           / column display format
# TTYPE13 = 'PSF_CENTR2'         / column title: PSF-fitted row centroid
# TFORM13 = 'D       '           / column format: 64-bit floating point
# TUNIT13 = 'pixel   '           / column units: pixel
# TDISP13 = 'F10.5   '           / column display format
# TTYPE14 = 'PSF_CENTR2_ERR'     / column title: PSF-fitted row error
# TFORM14 = 'E       '           / column format: 32-bit floating point
# TUNIT14 = 'pixel   '           / column units: pixel (1-sigma)
# TDISP14 = 'E14.7   '           / column display format
# TTYPE15 = 'MOM_CENTR1'         / column title: moment-derived column centroid
# TFORM15 = 'D       '           / column format: 64-bit floating point
# TUNIT15 = 'pixel   '           / column units: pixel
# TDISP15 = 'F10.5   '           / column display format
# TTYPE16 = 'MOM_CENTR1_ERR'     / column title: moment-derived column error
# TFORM16 = 'E       '           / column format: 32-bit floating point
# TUNIT16 = 'pixel   '           / column units: pixel (1-sigma)
# TDISP16 = 'E14.7   '           / column display format
# TTYPE17 = 'MOM_CENTR2'         / column title: moment-derived row centroid
# TFORM17 = 'D       '           / column format: 64-bit floating point
# TUNIT17 = 'pixel   '           / column units: pixel
# TDISP17 = 'F10.5   '           / column display format
# TTYPE18 = 'MOM_CENTR2_ERR'     / column title: moment-derived row error
# TFORM18 = 'E       '           / column format: 32-bit floating point
# TUNIT18 = 'pixel   '           / column units: pixel (1-sigma)
# TDISP18 = 'E14.7   '           / column display format
# TTYPE19 = 'POS_CORR1'          / column title: column position correction
# TFORM19 = 'E       '           / column format: 32-bit floating point
# TUNIT19 = 'pixels  '           / column units: pixel
# TDISP19 = 'E14.7   '           / column display format
# TTYPE20 = 'POS_CORR2'          / column title: row position correction
# TFORM20 = 'E       '           / column format: 32-bit floating point
# TUNIT20 = 'pixels  '           / column units: pixel
# TDISP20 = 'E14.7   '           / column display format
# INHERIT =                    T / inherit the primary header
# EXTNAME = 'LIGHTCURVE'         / name of extension
# EXTVER  =                    1 / extension version number (not format version)
# TELESCOP= 'Kepler  '           / telescope
# INSTRUME= 'Kepler Photometer'  / detector type
# OBJECT  = 'KIC 10525027'       / string version of target id
# KEPLERID=             10525027 / unique Kepler target identifier
# RADESYS = 'ICRS    '           / reference frame of celestial coordinates
# RA_OBJ  =           287.346729 / [deg] right ascension
# DEC_OBJ =            47.772960 / [deg] declination
# EQUINOX =               2000.0 / equinox of celestial coordinate system
# EXPOSURE=          30.83356943 / [d] time on source
# TIMEREF = 'SOLARSYSTEM'        / barycentric correction applied to times
# TASSIGN = 'SPACECRAFT'         / where time is assigned
# TIMESYS = 'TDB     '           / time system is barycentric JD
# BJDREFI =              2454833 / integer part of BJD reference date
# BJDREFF =           0.00000000 / fraction of the day in BJD reference date
# TIMEUNIT= 'd       '           / time unit for TIME, TSTART and TSTOP
# TELAPSE =          33.49163576 / [d] TSTOP - TSTART
# LIVETIME=          30.83356943 / [d] TELAPSE multiplied by DEADC
# TSTART  =         131.50212929 / observation start time in BJD-BJDREF
# TSTOP   =         164.99376505 / observation stop time in BJD-BJDREF
# LC_START=       54964.01099382 / mid point of first cadence in MJD
# LC_END  =       54997.48122492 / mid point of last cadence in MJD
# DEADC   =           0.92063492 / deadtime correction
# TIMEPIXR=                  0.5 / bin time beginning=0 middle=0.5 end=1
# TIERRELA=             5.78E-07 / [d] relative time error
# TIERABSO=                      / [d] absolute time error
# INT_TIME=       6.019802903270 / [s] photon accumulation time per frame
# READTIME=       0.518948526144 / [s] readout time per frame
# FRAMETIM=       6.538751429414 / [s] frame time (INT_TIME + READTIME)
# NUM_FRM =                  270 / number of frames per time stamp
# TIMEDEL =     0.02043359821692 / [d] time resolution of data
# DATE-OBS= '2009-05-13T00:01:07.136Z' / TSTART as UTC calendar date
# DATE-END= '2009-06-15T11:47:40.562Z' / TSTOP as UTC calendar date
# BACKAPP =                    T / background is subtracted
# DEADAPP =                    T / deadtime applied
# VIGNAPP =                    T / vignetting or collimator correction applied
# GAIN    =               114.37 / [electrons/count] channel gain
# READNOIS=            87.493050 / [electrons] read noise
# NREADOUT=                  270 / number of read per cadence
# TIMSLICE=                    1 / time-slice readout sequence section
# MEANBLCK=                  706 / [count] FSW mean black level
# LCFXDOFF=               419400 / long cadence fixed offset
# SCFXDOFF=               219400 / short cadence fixed offset
# CDPP3_0 =    91.40982818603516 / [ppm] RMS CDPP on 3.0-hr time scales
# CDPP6_0 =       71.47802734375 / [ppm] RMS CDPP on 6.0-hr time scales
# CDPP12_0=    56.87407684326172 / [ppm] RMS CDPP on 12.0-hr time scales
# CROWDSAP=               1.0000 / Ratio of target flux to total flux in op. ap.
# FLFRCSAP=               0.8796 / Frac. of target flux w/in the op. aperture
# NSPSDDET=                    0 / Number of SPSDs detected
# NSPSDCOR=                    0 / Number of SPSDs corrected
# PDCVAR  =    6.240415573120117 / Target variability
# PDCMETHD= 'regularMap'         / PDC algorithm used for target
# NUMBAND =                    1 / Number of scale bands
# FITTYPE1= 'prior   '           / Fit type used for band 1
# PR_GOOD1=   0.9387490153312683 / Prior goodness for band 1
# PR_WGHT1=    49.21261978149414 / Prior weight for band 1
# PDC_TOT =   0.9535799026489258 / PDC total goodness metric for target
# PDC_TOTP=   21.143274307250977 / PDC_TOT percentile compared to mod/out
# PDC_COR =   0.8477798104286194 / PDC correlation goodness metric for target
# PDC_CORP=   15.720315933227539 / PDC_COR percentile compared to mod/out
# PDC_VAR =   0.9993055462837219 / PDC variability goodness metric for target
# PDC_VARP=       31.16064453125 / PDC_VAR percentile compared to mod/out
# PDC_NOI =   0.9762303233146667 / PDC noise goodness metric for target
# PDC_NOIP=    79.38197326660156 / PDC_NOI percentile compared to mod/out
# PDC_EPT =                      / PDC earth point goodness metric for target
# PDC_EPTP=                      / PDC_EPT percentile compared to mod/out
# CHECKSUM= '7jCD9jBC7jBC7jBC'   / HDU checksum updated 2015-09-01T14:43:57Z

# %%
alltime_noclip = []
allflux_noclip = []
allfluxerr_noclip = []

for sublist in t:
    for item in sublist:
        alltime_noclip.append(item)
        
for sublist in f:
    for item in sublist:
        allflux_noclip.append(item)
        
for sublist in fe:
    for item in sublist:
        allfluxerr_noclip.append(item)

# %%
def sigma_clip(time, flux, fluxerr, sig=4):
    for i in tqdm(range(len(flux))):
        if flux[i] > np.nanmean(flux) + sig*np.nanstd(flux) or flux[i] < np.nanmean(flux) - sig*np.nanstd(flux):
            time[i] = np.nan
            flux[i] = np.nan
            fluxerr[i] = np.nan
            
    return time, flux, fluxerr

# %%
# alltime, allflux, allfluxerr = sigma_clip(alltime_noclip, allflux_noclip, allfluxerr_noclip, sig=4)

alltime, allflux, allfluxerr = alltime_noclip, allflux_noclip, allfluxerr_noclip

plt.scatter(alltime, allflux, s=1)
plt.title('KOI 4290')
# Out:
# Text(0.5, 1.0, 'KOI 4290')

# %% [markdown]
# # Kepler-1582 b

# %%
kepid = 5868793
kepname = spectplanets.loc[spectplanets['kepid'] == kepid].kepler_name.values[0]

# %%
isodf = pd.read_csv("datafiles/isochrones/iso_lums_" + str(kepid) + ".csv")

mstar = isodf["mstar"].mean()
mstar_err = isodf["mstar"].std()

rstar = isodf["radius"].mean()
rstar_err = isodf["radius"].std()

# %%
period, period_uerr, period_lerr, rprs, rprs_uerr, rprs_lerr, a_arc, a_uerr_arc, a_lerr_arc, i, e_arc, w_arc = ph.planet_params_from_archive(spectplanets, kepname)

# We calculate a_rs to ensure that it's consistent with the spec/Gaia stellar density.
a_rs = ph.calc_a(period*86400.0, mstar*smass_kg, rstar*srad_m)
a_rs_err = np.mean((a_uerr_arc, a_lerr_arc))

print('Stellar mass (Msun): ', mstar, 'Stellar radius (Rsun): ', rstar)
print('Period (Days): ', period, 'Rp/Rs: ', rprs)
print('a/Rs: ', a_rs)
print('i (deg): ', i)
# Out:
# Stellar mass (Msun):  0.17438311970562165 Stellar radius (Rsun):  0.19884797856314
# Period (Days):  4.83809469 Rp/Rs:  0.036066
# a/Rs:  33.79155851141583
# i (deg):  89.98

# %%
transitmpt = 2454968.1468

# %%
midpoints = np.arange(alltime[0], alltime[-1], period)

# %%
alltime[0]
# Out:
# 2454964.51234641

# %%
plt.scatter(alltime, allflux, s=2)

for i in range(len(midpoints)):
    plt.axvline(midpoints[i], c='r')
    
plt.xlim(alltime[0], alltime[0] + 50)
# Out:
# (2454964.51234641, 2455014.51234641)

# %%
#midpoints = np.unique(list(midjd[midjd['planetname'] == 'Kepler-737 b']['midpointjd']))
#midpoints_errs = np.unique(list(midjd[midjd['username'] == 'KOI ' + '947']['propmidpointunc']))

# %%
def get_KIC(KOI, muirhead_comb):
    return muirhead_comb[muirhead_comb['KOI'] == str(KOI)].KIC.item()

# %%
def fit_Kepler_lc(KOI, midpoints, time, flux, flux_err, period, nbuffer, spectplanets, muirhead_comb):
    
    # Get alt IDs
    kepid = get_KIC(KOI, muirhead_comb)
    kepname = spectplanets.loc[spectplanets['kepid'] == kepid].kepler_name.values[0]
    
    dr = str(KOI)
    direct = 'segfits/' + dr + '_NEW/'

    if not os.path.exists(direct):
        os.mkdir(direct)
    
    # Get stellar params
    isodf = pd.read_csv("datafiles/isochrones/iso_lums_" + str(kepid) + ".csv")
    
    mstar = isodf["mstar"].mean()
    mstar_err = isodf["mstar"].std()

    rstar = isodf["radius"].mean()
    rstar_err = isodf["radius"].std()
    
    # Get planet params
    period, period_uerr, period_lerr, rprs, rprs_uerr, rprs_lerr, a_arc, a_uerr_arc, a_lerr_arc, i, e_arc, w_arc = ph.planet_params_from_archive(spectplanets, kepname)

    # We calculate a_rs to ensure that it's consistent with the spec/Gaia stellar density.
    a_rs = ph.calc_a(period*86400.0, mstar*smass_kg, rstar*srad_m)
    a_rs_err = np.mean((a_uerr_arc, a_lerr_arc))

    print('Stellar mass (Msun): ', mstar, 'Stellar radius (Rsun): ', rstar)
    print('Period (Days): ', period, 'Rp/Rs: ', rprs)
    print('a/Rs: ', a_rs)
    print('i (deg): ', i)
            
    
    for ind in range(len(midpoints)):

        try:
        
            transitmid = midpoints[ind]

            tindex = int(np.where(alltime == ph.find_nearest(alltime, transitmid))[0])

            t1 = np.array(time[tindex-nbuffer:tindex+nbuffer]) - transitmid
            f1 = np.array(flux[tindex-nbuffer:tindex+nbuffer])
            fe1 = np.array(flux_err[tindex-nbuffer:tindex+nbuffer])

            tindex = int(np.where(time == ph.find_nearest(time, transitmid))[0])

            idx = np.isfinite(t1) & np.isfinite(f1)

            disc = 4
            m, b = np.polyfit(np.concatenate((t1[idx][:disc], t1[idx][-disc:])), np.concatenate((f1[idx][:disc], f1[idx][-disc:])), 1)

            linfit = m*t1 + b
            fnorm = (f1-linfit)+1
            
            plt.cla()
            plt.errorbar(t1, f1, yerr=fe1, fmt='o', c='blue')
            plt.plot(t1, linfit, c='green')
            plt.xlabel('Time')
            plt.ylabel('Rel. Flux')
            plt.axvline(0, c='r')
            plt.savefig(direct + str(KOI) + 'segment' + str(ind) + '.png')

            mid = ph.get_mid(time)
            ptime = ph.get_ptime(t1, mid, 29)

            fnorm = np.nan_to_num(fnorm, nan=1.0)
            fe1 = np.nan_to_num(fe1, nan=np.nanmedian(fe1))


            # Inital guess: rprs, a/Rs, i, t0
            p0 = [rprs, a_rs, i, 0]

            # EMCEE Transit Model Fitting
            _, _, rdist, adist, idist, t0dist = ph.mcmc_fitter_noper(p0, period, t1, ptime, fnorm, fe1, nwalk, nsteps_d, ndiscard_d, 'X', 'X', direct, plot_Tburnin=False, plot_Tcorner=False)
            
            # Create a light curve with the fit parameters
            mcmcfit = ph.integratedlc_fitter(t1, period, ph.mode(rdist), ph.mode(adist), ph.mode(idist), ph.mode(t0dist))
            truefit = ph.integratedlc_fitter(t1, period, rprs, a_rs, i, 0)

            plt.cla()
            plt.errorbar(t1, fnorm, yerr=fe1, c='blue', alpha=0.5, label='Original LC', fmt="o", capsize=0)
            plt.scatter(t1, mcmcfit, c='red', alpha=1.0, label='Fit LC')
            plt.plot(t1, mcmcfit, c='red', alpha=1.0)
            plt.plot(t1, truefit, c='green', alpha=1.0)
            
            textstr = '\n'.join((
            r'$\mathrm{Rp/Rs}=%.2f$' % (ph.mode(rdist), ),
            r'$\mathrm{a_rs}=%.2f$' % (ph.mode(adist), ),
            r'$\mathrm{i}=%.2f$' % (ph.mode(idist), ),
            r'$\mathrm{t0}=%.2f$' % (ph.mode(t0dist), )))
            plt.title(textstr)

            plt.legend()
            
            plt.savefig(direct + str(KOI) + 'segment' + str(ind) + 'fit.png')
            
            
        # Skip if transit mid-time falls outside of Kepler observations
        except TypeError:
            continue

# %%
fit_Kepler_lc(4290, midpoints, alltime, allflux, allfluxerr, period, 12, spectplanets, muirhead_comb)
# Out:
#   0%|          | 0/1500 [00:00<?, ?it/s]
# Stellar mass (Msun):  0.17438311970562165 Stellar radius (Rsun):  0.19884797856314
# Period (Days):  4.83809469 Rp/Rs:  0.036066
# a/Rs:  33.79155851141583
# i (deg):  89.98
# 100%|██████████| 1500/1500 [00:52<00:00, 28.42it/s]
# 100%|██████████| 1500/1500 [00:53<00:00, 28.11it/s]
# 100%|██████████| 1500/1500 [00:54<00:00, 27.70it/s]
# 100%|██████████| 1500/1500 [00:55<00:00, 27.13it/s]
# 100%|██████████| 1500/1500 [00:53<00:00, 28.04it/s]
# 100%|██████████| 1500/1500 [00:55<00:00, 26.91it/s]
# 100%|██████████| 1500/1500 [00:56<00:00, 26.72it/s]
# 100%|██████████| 1500/1500 [00:54<00:00, 27.65it/s]
# 100%|██████████| 1500/1500 [01:04<00:00, 23.39it/s]
# 100%|██████████| 1500/1500 [01:05<00:00, 22.99it/s]
# 100%|██████████| 1500/1500 [00:54<00:00, 27.65it/s]
# 100%|██████████| 1500/1500 [00:52<00:00, 28.41it/s]
#  47%|████▋     | 701/1500 [00:27<00:31, 25.41it/s]Traceback (most recent call last):
#   File "/Users/ssagear/anaconda3/lib/python3.8/site-packages/emcee/ensemble.py", line 545, in __call__
#     return self.f(x, *self.args, **self.kwargs)
#   File "/Users/ssagear/Dropbox (UFL)/Research/MetallicityProject/photoeccentric/photoeccentric/photoeccentric.py", line 978, in tfit_noper_log_probability
#     return lp + tfit_noper_log_likelihood(theta, per, time, ptime, flux, flux_err)
#   File "/Users/ssagear/Dropbox (UFL)/Research/MetallicityProject/photoeccentric/photoeccentric/photoeccentric.py", line 952, in tfit_noper_log_likelihood
#     model = integratedlc_fitter(time, per, rp, a, inc, t0)
#   File "/Users/ssagear/Dropbox (UFL)/Research/MetallicityProject/photoeccentric/photoeccentric/lcfitter.py", line 169, in integratedlc_fitter
#     flux = array_integrated(pflux, 29)
#   File "/Users/ssagear/Dropbox (UFL)/Research/MetallicityProject/photoeccentric/photoeccentric/lcfitter.py", line 287, in array_integrated
#     arr = np.mean(np.array(arr), axis=1)
# KeyboardInterrupt
#  47%|████▋     | 702/1500 [00:27<00:31, 25.45it/s]
# emcee: Exception while calling your likelihood function:
#   params: [ 6.12500639e-01  1.52786390e+07  5.97544629e+01 -2.21769517e-02]
#   args: (4.83809469, array([-0.24616762, -0.22573384, -0.20529986, -0.18486598, -0.1644322 ,
#        -0.14399823, -0.12356435, -0.10313047, -0.08269669, -0.06226271,
#        -0.04182883, -0.02139504, -0.00096106,  0.01947282,  0.0399066 ,
#         0.06034058,  0.08077446,  0.10120824,  0.12164223,  0.14207611,
#         0.16250989,  0.18294387,  0.20337776,  0.22381164]), array([-2.56384174e-01, -2.55654420e-01, -2.54924666e-01, -2.54194912e-01,
#        -2.53465158e-01, -2.52735405e-01, -2.52005651e-01, -2.51275897e-01,
#        -2.50546143e-01, -2.49816389e-01, -2.49086635e-01, -2.48356881e-01,
#        -2.47627127e-01, -2.46897373e-01, -2.46167619e-01, -2.45437865e-01,
#        -2.44708111e-01, -2.43978357e-01, -2.43248604e-01, -2.42518850e-01,
#        -2.41789096e-01, -2.41059342e-01, -2.40329588e-01, -2.39599834e-01,
#        -2.38870080e-01, -2.38140326e-01, -2.37410572e-01, -2.36680818e-01,
#        -2.35951064e-01, -2.35950396e-01, -2.35220642e-01, -2.34490888e-01,
#        -2.33761134e-01, -2.33031380e-01, -2.32301626e-01, -2.31571872e-01,
#        -2.30842118e-01, -2.30112364e-01, -2.29382610e-01, -2.28652857e-01,
#        -2.27923103e-01, -2.27193349e-01, -2.26463595e-01, -2.25733841e-01,
#        -2.25004087e-01, -2.24274333e-01, -2.23544579e-01, -2.22814825e-01,
#        -2.22085071e-01, -2.21355317e-01, -2.20625563e-01, -2.19895809e-01,
#        -2.19166056e-01, -2.18436302e-01, -2.17706548e-01, -2.16976794e-01,
#        -2.16247040e-01, -2.15517286e-01, -2.15516417e-01, -2.14786663e-01,
#        -2.14056909e-01, -2.13327155e-01, -2.12597401e-01, -2.11867647e-01,
#        -2.11137894e-01, -2.10408140e-01, -2.09678386e-01, -2.08948632e-01,
#        -2.08218878e-01, -2.07489124e-01, -2.06759370e-01, -2.06029616e-01,
#        -2.05299862e-01, -2.04570108e-01, -2.03840354e-01, -2.03110600e-01,
#        -2.02380847e-01, -2.01651093e-01, -2.00921339e-01, -2.00191585e-01,
#        -1.99461831e-01, -1.98732077e-01, -1.98002323e-01, -1.97272569e-01,
#        -1.96542815e-01, -1.95813061e-01, -1.95083307e-01, -1.95082538e-01,
#        -1.94352784e-01, -1.93623030e-01, -1.92893276e-01, -1.92163522e-01,
#        -1.91433768e-01, -1.90704015e-01, -1.89974261e-01, -1.89244507e-01,
#        -1.88514753e-01, -1.87784999e-01, -1.87055245e-01, -1.86325491e-01,
#        -1.85595737e-01, -1.84865983e-01, -1.84136229e-01, -1.83406475e-01,
#        -1.82676721e-01, -1.81946968e-01, -1.81217214e-01, -1.80487460e-01,
#        -1.79757706e-01, -1.79027952e-01, -1.78298198e-01, -1.77568444e-01,
#        -1.76838690e-01, -1.76108936e-01, -1.75379182e-01, -1.74649428e-01,
#        -1.74648759e-01, -1.73919005e-01, -1.73189251e-01, -1.72459497e-01,
#        -1.71729744e-01, -1.70999990e-01, -1.70270236e-01, -1.69540482e-01,
#        -1.68810728e-01, -1.68080974e-01, -1.67351220e-01, -1.66621466e-01,
#        -1.65891712e-01, -1.65161958e-01, -1.64432204e-01, -1.63702450e-01,
#        -1.62972696e-01, -1.62242943e-01, -1.61513189e-01, -1.60783435e-01,
#        -1.60053681e-01, -1.59323927e-01, -1.58594173e-01, -1.57864419e-01,
#        -1.57134665e-01, -1.56404911e-01, -1.55675157e-01, -1.54945403e-01,
#        -1.54215649e-01, -1.54214780e-01, -1.53485026e-01, -1.52755272e-01,
#        -1.52025518e-01, -1.51295764e-01, -1.50566010e-01, -1.49836257e-01,
#        -1.49106503e-01, -1.48376749e-01, -1.47646995e-01, -1.46917241e-01,
#        -1.46187487e-01, -1.45457733e-01, -1.44727979e-01, -1.43998225e-01,
#        -1.43268471e-01, -1.42538717e-01, -1.41808963e-01, -1.41079210e-01,
#        -1.40349456e-01, -1.39619702e-01, -1.38889948e-01, -1.38160194e-01,
#        -1.37430440e-01, -1.36700686e-01, -1.35970932e-01, -1.35241178e-01,
#        -1.34511424e-01, -1.33781670e-01, -1.33780901e-01, -1.33051147e-01,
#        -1.32321393e-01, -1.31591639e-01, -1.30861885e-01, -1.30132131e-01,
#        -1.29402377e-01, -1.28672623e-01, -1.27942869e-01, -1.27213115e-01,
#        -1.26483361e-01, -1.25753608e-01, -1.25023854e-01, -1.24294100e-01,
#        -1.23564346e-01, -1.22834592e-01, -1.22104838e-01, -1.21375084e-01,
#        -1.20645330e-01, -1.19915576e-01, -1.19185822e-01, -1.18456068e-01,
#        -1.17726314e-01, -1.16996560e-01, -1.16266807e-01, -1.15537053e-01,
#        -1.14807299e-01, -1.14077545e-01, -1.13347791e-01, -1.13347021e-01,
#        -1.12617267e-01, -1.11887513e-01, -1.11157759e-01, -1.10428005e-01,
#        -1.09698251e-01, -1.08968497e-01, -1.08238743e-01, -1.07508989e-01,
#        -1.06779235e-01, -1.06049482e-01, -1.05319728e-01, -1.04589974e-01,
#        -1.03860220e-01, -1.03130466e-01, -1.02400712e-01, -1.01670958e-01,
#        -1.00941204e-01, -1.00211450e-01, -9.94816962e-02, -9.87519423e-02,
#        -9.80221884e-02, -9.72924345e-02, -9.65626806e-02, -9.58329267e-02,
#        -9.51031727e-02, -9.43734188e-02, -9.36436649e-02, -9.29139110e-02,
#        -9.29132409e-02, -9.21834870e-02, -9.14537331e-02, -9.07239791e-02,
#        -8.99942252e-02, -8.92644713e-02, -8.85347174e-02, -8.78049635e-02,
#        -8.70752095e-02, -8.63454556e-02, -8.56157017e-02, -8.48859478e-02,
#        -8.41561939e-02, -8.34264400e-02, -8.26966860e-02, -8.19669321e-02,
#        -8.12371782e-02, -8.05074243e-02, -7.97776704e-02, -7.90479164e-02,
#        -7.83181625e-02, -7.75884086e-02, -7.68586547e-02, -7.61289008e-02,
#        -7.53991468e-02, -7.46693929e-02, -7.39396390e-02, -7.32098851e-02,
#        -7.24801312e-02, -7.24792609e-02, -7.17495069e-02, -7.10197530e-02,
#        -7.02899991e-02, -6.95602452e-02, -6.88304913e-02, -6.81007373e-02,
#        -6.73709834e-02, -6.66412295e-02, -6.59114756e-02, -6.51817217e-02,
#        -6.44519677e-02, -6.37222138e-02, -6.29924599e-02, -6.22627060e-02,
#        -6.15329521e-02, -6.08031982e-02, -6.00734442e-02, -5.93436903e-02,
#        -5.86139364e-02, -5.78841825e-02, -5.71544286e-02, -5.64246746e-02,
#        -5.56949207e-02, -5.49651668e-02, -5.42354129e-02, -5.35056590e-02,
#        -5.27759051e-02, -5.20461511e-02, -5.20453805e-02, -5.13156265e-02,
#        -5.05858726e-02, -4.98561187e-02, -4.91263648e-02, -4.83966109e-02,
#        -4.76668570e-02, -4.69371030e-02, -4.62073491e-02, -4.54775952e-02,
#        -4.47478413e-02, -4.40180874e-02, -4.32883334e-02, -4.25585795e-02,
#        -4.18288256e-02, -4.10990717e-02, -4.03693178e-02, -3.96395638e-02,
#        -3.89098099e-02, -3.81800560e-02, -3.74503021e-02, -3.67205482e-02,
#        -3.59907943e-02, -3.52610403e-02, -3.45312864e-02, -3.38015325e-02,
#        -3.30717786e-02, -3.23420247e-02, -3.16122707e-02, -3.16115997e-02,
#        -3.08818458e-02, -3.01520919e-02, -2.94223380e-02, -2.86925841e-02,
#        -2.79628301e-02, -2.72330762e-02, -2.65033223e-02, -2.57735684e-02,
#        -2.50438145e-02, -2.43140605e-02, -2.35843066e-02, -2.28545527e-02,
#        -2.21247988e-02, -2.13950449e-02, -2.06652909e-02, -1.99355370e-02,
#        -1.92057831e-02, -1.84760292e-02, -1.77462753e-02, -1.70165214e-02,
#        -1.62867674e-02, -1.55570135e-02, -1.48272596e-02, -1.40975057e-02,
#        -1.33677518e-02, -1.26379978e-02, -1.19082439e-02, -1.11784900e-02,
#        -1.11776188e-02, -1.04478648e-02, -9.71811092e-03, -8.98835700e-03,
#        -8.25860308e-03, -7.52884916e-03, -6.79909524e-03, -6.06934133e-03,
#        -5.33958741e-03, -4.60983349e-03, -3.88007957e-03, -3.15032565e-03,
#        -2.42057173e-03, -1.69081781e-03, -9.61063895e-04, -2.31309977e-04,
#         4.98443942e-04,  1.22819786e-03,  1.95795178e-03,  2.68770570e-03,
#         3.41745962e-03,  4.14721353e-03,  4.87696745e-03,  5.60672137e-03,
#         6.33647529e-03,  7.06622921e-03,  7.79598313e-03,  8.52573705e-03,
#         9.25549096e-03,  9.25626257e-03,  9.98601648e-03,  1.07157704e-02,
#         1.14455243e-02,  1.21752782e-02,  1.29050322e-02,  1.36347861e-02,
#         1.43645400e-02,  1.50942939e-02,  1.58240478e-02,  1.65538018e-02,
#         1.72835557e-02,  1.80133096e-02,  1.87430635e-02,  1.94728174e-02,
#         2.02025713e-02,  2.09323253e-02,  2.16620792e-02,  2.23918331e-02,
#         2.31215870e-02,  2.38513409e-02,  2.45810949e-02,  2.53108488e-02,
#         2.60406027e-02,  2.67703566e-02,  2.75001105e-02,  2.82298644e-02,
#         2.89596184e-02,  2.96893723e-02,  2.96900438e-02,  3.04197977e-02,
#         3.11495516e-02,  3.18793055e-02,  3.26090594e-02,  3.33388134e-02,
#         3.40685673e-02,  3.47983212e-02,  3.55280751e-02,  3.62578290e-02,
#         3.69875830e-02,  3.77173369e-02,  3.84470908e-02,  3.91768447e-02,
#         3.99065986e-02,  4.06363525e-02,  4.13661065e-02,  4.20958604e-02,
#         4.28256143e-02,  4.35553682e-02,  4.42851221e-02,  4.50148761e-02,
#         4.57446300e-02,  4.64743839e-02,  4.72041378e-02,  4.79338917e-02,
#         4.86636457e-02,  4.93933996e-02,  5.01231535e-02,  5.01240257e-02,
#         5.08537796e-02,  5.15835335e-02,  5.23132874e-02,  5.30430413e-02,
#         5.37727953e-02,  5.45025492e-02,  5.52323031e-02,  5.59620570e-02,
#         5.66918109e-02,  5.74215649e-02,  5.81513188e-02,  5.88810727e-02,
#         5.96108266e-02,  6.03405805e-02,  6.10703344e-02,  6.18000884e-02,
#         6.25298423e-02,  6.32595962e-02,  6.39893501e-02,  6.47191040e-02,
#         6.54488580e-02,  6.61786119e-02,  6.69083658e-02,  6.76381197e-02,
#         6.83678736e-02,  6.90976276e-02,  6.98273815e-02,  7.05571354e-02,
#         7.05579075e-02,  7.12876614e-02,  7.20174153e-02,  7.27471692e-02,
#         7.34769231e-02,  7.42066770e-02,  7.49364310e-02,  7.56661849e-02,
#         7.63959388e-02,  7.71256927e-02,  7.78554466e-02,  7.85852006e-02,
#         7.93149545e-02,  8.00447084e-02,  8.07744623e-02,  8.15042162e-02,
#         8.22339702e-02,  8.29637241e-02,  8.36934780e-02,  8.44232319e-02,
#         8.51529858e-02,  8.58827397e-02,  8.66124937e-02,  8.73422476e-02,
#         8.80720015e-02,  8.88017554e-02,  8.95315093e-02,  9.02612633e-02,
#         9.09910172e-02,  9.09916896e-02,  9.17214435e-02,  9.24511974e-02,
#         9.31809513e-02,  9.39107053e-02,  9.46404592e-02,  9.53702131e-02,
#         9.60999670e-02,  9.68297209e-02,  9.75594749e-02,  9.82892288e-02,
#         9.90189827e-02,  9.97487366e-02,  1.00478491e-01,  1.01208244e-01,
#         1.01937998e-01,  1.02667752e-01,  1.03397506e-01,  1.04127260e-01,
#         1.04857014e-01,  1.05586768e-01,  1.06316522e-01,  1.07046276e-01,
#         1.07776030e-01,  1.08505784e-01,  1.09235538e-01,  1.09965291e-01,
#         1.10695045e-01,  1.11424799e-01,  1.11425672e-01,  1.12155426e-01,
#         1.12885180e-01,  1.13614934e-01,  1.14344688e-01,  1.15074442e-01,
#         1.15804195e-01,  1.16533949e-01,  1.17263703e-01,  1.17993457e-01,
#         1.18723211e-01,  1.19452965e-01,  1.20182719e-01,  1.20912473e-01,
#         1.21642227e-01,  1.22371981e-01,  1.23101735e-01,  1.23831489e-01,
#         1.24561242e-01,  1.25290996e-01,  1.26020750e-01,  1.26750504e-01,
#         1.27480258e-01,  1.28210012e-01,  1.28939766e-01,  1.29669520e-01,
#         1.30399274e-01,  1.31129028e-01,  1.31858782e-01,  1.31859554e-01,
#         1.32589308e-01,  1.33319062e-01,  1.34048816e-01,  1.34778570e-01,
#         1.35508324e-01,  1.36238078e-01,  1.36967832e-01,  1.37697586e-01,
#         1.38427339e-01,  1.39157093e-01,  1.39886847e-01,  1.40616601e-01,
#         1.41346355e-01,  1.42076109e-01,  1.42805863e-01,  1.43535617e-01,
#         1.44265371e-01,  1.44995125e-01,  1.45724879e-01,  1.46454633e-01,
#         1.47184387e-01,  1.47914140e-01,  1.48643894e-01,  1.49373648e-01,
#         1.50103402e-01,  1.50833156e-01,  1.51562910e-01,  1.52292664e-01,
#         1.52293337e-01,  1.53023091e-01,  1.53752845e-01,  1.54482599e-01,
#         1.55212353e-01,  1.55942107e-01,  1.56671861e-01,  1.57401615e-01,
#         1.58131369e-01,  1.58861123e-01,  1.59590876e-01,  1.60320630e-01,
#         1.61050384e-01,  1.61780138e-01,  1.62509892e-01,  1.63239646e-01,
#         1.63969400e-01,  1.64699154e-01,  1.65428908e-01,  1.66158662e-01,
#         1.66888416e-01,  1.67618170e-01,  1.68347923e-01,  1.69077677e-01,
#         1.69807431e-01,  1.70537185e-01,  1.71266939e-01,  1.71996693e-01,
#         1.72726447e-01,  1.72727320e-01,  1.73457074e-01,  1.74186828e-01,
#         1.74916582e-01,  1.75646336e-01,  1.76376090e-01,  1.77105844e-01,
#         1.77835598e-01,  1.78565351e-01,  1.79295105e-01,  1.80024859e-01,
#         1.80754613e-01,  1.81484367e-01,  1.82214121e-01,  1.82943875e-01,
#         1.83673629e-01,  1.84403383e-01,  1.85133137e-01,  1.85862891e-01,
#         1.86592645e-01,  1.87322398e-01,  1.88052152e-01,  1.88781906e-01,
#         1.89511660e-01,  1.90241414e-01,  1.90971168e-01,  1.91700922e-01,
#         1.92430676e-01,  1.93160430e-01,  1.93161204e-01,  1.93890958e-01,
#         1.94620712e-01,  1.95350466e-01,  1.96080219e-01,  1.96809973e-01,
#         1.97539727e-01,  1.98269481e-01,  1.98999235e-01,  1.99728989e-01,
#         2.00458743e-01,  2.01188497e-01,  2.01918251e-01,  2.02648005e-01,
#         2.03377759e-01,  2.04107513e-01,  2.04837266e-01,  2.05567020e-01,
#         2.06296774e-01,  2.07026528e-01,  2.07756282e-01,  2.08486036e-01,
#         2.09215790e-01,  2.09945544e-01,  2.10675298e-01,  2.11405052e-01,
#         2.12134806e-01,  2.12864560e-01,  2.13594313e-01,  2.13595087e-01,
#         2.14324841e-01,  2.15054595e-01,  2.15784349e-01,  2.16514103e-01,
#         2.17243857e-01,  2.17973610e-01,  2.18703364e-01,  2.19433118e-01,
#         2.20162872e-01,  2.20892626e-01,  2.21622380e-01,  2.22352134e-01,
#         2.23081888e-01,  2.23811642e-01,  2.24541396e-01,  2.25271150e-01,
#         2.26000904e-01,  2.26730657e-01,  2.27460411e-01,  2.28190165e-01,
#         2.28919919e-01,  2.29649673e-01,  2.30379427e-01,  2.31109181e-01,
#         2.31838935e-01,  2.32568689e-01,  2.33298443e-01,  2.34028197e-01]), array([0.99996482, 1.00035531, 0.99976251, 0.99991185, 1.00022092,
#        1.        , 0.999886  , 0.99991845, 1.00007619, 1.00022678,
#        0.99991239, 1.00026456, 0.99990028, 1.0000585 , 1.00001161,
#        1.00008704, 0.99973588, 1.00017382, 1.00003896, 1.0002867 ,
#        0.9999738 , 0.99992912, 0.99996307, 1.00013952]), array([0.00017763, 0.00017766, 0.00017762, 0.00017763, 0.00017765,
#        0.00017763, 0.00017762, 0.00017762, 0.00017763, 0.00017762,
#        0.00017764, 0.00017761, 0.0001776 , 0.00017763, 0.00017763,
#        0.0001776 , 0.00017761, 0.00017764, 0.00017764, 0.00017765,
#        0.00017766, 0.00017759, 0.00017761, 0.00017762], dtype=float32))
#   kwargs: {}
#   exception:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-84-acc785cf13db> in <module>
# ----> 1 fit_Kepler_lc(4290, midpoints, alltime, allflux, allfluxerr, period, 12, spectplanets, muirhead_comb)
#
# <ipython-input-83-c363d06c92d6> in fit_Kepler_lc(KOI, midpoints, time, flux, flux_err, period, nbuffer, spectplanets, muirhead_comb)
#      74
#      75             # EMCEE Transit Model Fitting
# ---> 76             _, _, rdist, adist, idist, t0dist = ph.mcmc_fitter_noper(p0, period, t1, ptime, fnorm, fe1, nwalk, nsteps_d, ndiscard_d, 'X', 'X', direct, plot_Tburnin=False, plot_Tcorner=False)
#      77
#      78             # Create a light curve with the fit parameters
#
# ~/Dropbox (UFL)/Research/MetallicityProject/photoeccentric/photoeccentric/photoeccentric.py in mcmc_fitter_noper(guess_transit, per, time, ptime, nflux, flux_err, nwalk, nsteps, ndiscard, e, w, directory, plot_Tburnin, plot_Tcorner)
#    1036
#    1037     sampler = emcee.EnsembleSampler(nwalkers, ndim, tfit_noper_log_probability, args=(per, time, ptime, nflux, flux_err), threads=4)
# -> 1038     sampler.run_mcmc(pos, nsteps, progress=True);
#    1039     samples = sampler.get_chain()
#    1040
#
# ~/anaconda3/lib/python3.8/site-packages/emcee/ensemble.py in run_mcmc(self, initial_state, nsteps, **kwargs)
#     382
#     383         results = None
# --> 384         for results in self.sample(initial_state, iterations=nsteps, **kwargs):
#     385             pass
#     386
#
# ~/anaconda3/lib/python3.8/site-packages/emcee/ensemble.py in sample(self, initial_state, log_prob0, rstate0, blobs0, iterations, tune, skip_initial_state_check, thin_by, thin, store, progress)
#     341
#     342                     # Propose
# --> 343                     state, accepted = move.propose(model, state)
#     344                     state.random_state = self.random_state
#     345
#
# ~/anaconda3/lib/python3.8/site-packages/emcee/moves/red_blue.py in propose(self, model, state)
#      91
#      92             # Compute the lnprobs of the proposed position.
# ---> 93             new_log_probs, new_blobs = model.compute_log_prob_fn(q)
#      94
#      95             # Loop over the walkers and update them accordingly.
#
# ~/anaconda3/lib/python3.8/site-packages/emcee/ensemble.py in compute_log_prob(self, coords)
#     424             else:
#     425                 map_func = map
# --> 426             results = list(
#     427                 map_func(self.log_prob_fn, (p[i] for i in range(len(p))))
#     428             )
#
# ~/anaconda3/lib/python3.8/site-packages/emcee/ensemble.py in __call__(self, x)
#     543     def __call__(self, x):
#     544         try:
# --> 545             return self.f(x, *self.args, **self.kwargs)
#     546         except:  # pragma: no cover
#     547             import traceback
#
# ~/Dropbox (UFL)/Research/MetallicityProject/photoeccentric/photoeccentric/photoeccentric.py in tfit_noper_log_probability(theta, per, time, ptime, flux, flux_err)
#     976     if not np.isfinite(lp):
#     977         return -np.inf
# --> 978     return lp + tfit_noper_log_likelihood(theta, per, time, ptime, flux, flux_err)
#     979
#     980 ##############################################################################################
#
# ~/Dropbox (UFL)/Research/MetallicityProject/photoeccentric/photoeccentric/photoeccentric.py in tfit_noper_log_likelihood(theta, per, time, ptime, flux, flux_err)
#     950     rp, a, inc, t0 = theta
#     951
# --> 952     model = integratedlc_fitter(time, per, rp, a, inc, t0)
#     953     sigma2 = flux_err ** 2
#     954
#
# ~/Dropbox (UFL)/Research/MetallicityProject/photoeccentric/photoeccentric/lcfitter.py in integratedlc_fitter(time, per, rp, ars, inc, t0)
#     167
#     168     pflux = m.light_curve(params)
# --> 169     flux = array_integrated(pflux, 29)
#     170
#     171     return flux
#
# ~/Dropbox (UFL)/Research/MetallicityProject/photoeccentric/photoeccentric/lcfitter.py in array_integrated(arr, nint)
#     285
#     286     arr = list(divide_chunks(arr, nint))
# --> 287     arr = np.mean(np.array(arr), axis=1)
#     288
#     289     return arr
#
# KeyboardInterrupt:

# %%
t0 = hdu[1].header['BJDREFI']
tm1 = hdu[1].header['BJDREFI']+period*100
tmidtimes = np.arange(t0, tm1, period)

# %%
midjd = pd.read_csv('/Users/ssagear/Dropbox (UFL)/Research/MetallicityProject/photoeccentric/notebooks/datafiles/keplerstellar/transitmpts/MuirheadKOIs_4_MPTS.csv', comment='#')

# %%
midpoints = [item for item in midjd[midjd['username'] == 'KOI 947']['midpointjd']]
midpoints_errs = [item for item in midjd[midjd['username'] == 'KOI 947']['propmidpointunc']]

# %%
#cmtimes[6] = cmtimes[6] + 0.017
#cmtimes[-6] = cmtimes[-6] - 0.017

mp = 1

transitmid = cmtimes[mp]
transitmid_err = cmerrors[mp]

transitmid = cmtimes[mp]

# %%
start = hdu[1].header['TSTART'] + hdu[1].header['BJDREFI']
end = hdu[1].header['TSTOP'] + hdu[1].header['BJDREFI']

# %%
mid = ph.get_mid(alltime)

# %%
tindex = int(np.where(alltime == ph.find_nearest(alltime, transitmid))[0])

# %%
n = 6

t1 = np.array(alltime[tindex-n:tindex+n]) - transitmid
f1 = np.array(allflux[tindex-n:tindex+n])
fe1 = np.array(allfluxerr[tindex-n:tindex+n])

# %%
# plt.errorbar(alltime, allflux, yerr=allfluxerr, fmt='o')
# plt.axvline(cmtimes[5], c='r')
# plt.axvline(cmtimes[6], c='r')
# plt.xlim(cmtimes[5]-3, cmtimes[6]+3)
# plt.ylim(.990, 1.010)

# %%
plt.errorbar(t1, f1, yerr=fe1)
#plt.axvline(0+transitmid_err, c='r')
#plt.axvline(0-transitmid_err, c='r')
plt.axvline(0, c='r')

# %%
idx = np.isfinite(t1) & np.isfinite(f1)
print(idx)
disc = 3

a, b, c = np.polyfit(np.concatenate((t1[idx][:disc], t1[idx][-disc:])), np.concatenate((f1[idx][:disc], f1[idx][-disc:])), 2)
m, b = np.polyfit(np.concatenate((t1[idx][:disc], t1[idx][-disc:])), np.concatenate((f1[idx][:disc], f1[idx][-disc:])), 1)


plt.scatter(np.concatenate((t1[idx][:disc], t1[idx][-disc:])), np.concatenate((f1[idx][:disc], f1[idx][-disc:])))
# Out:
# [ True  True  True  True  True  True  True  True  True  True  True  True]

# %%
plt.plot(t1, m*t1 + b, c='g')
#plt.plot(t1, a*t1**2 + b*t1 + c, c='g')
plt.errorbar(t1, f1, yerr=fe1, fmt='o')
plt.axvline(0, c='r')

# %%
linfit = m*t1 + b
fnorm = (f1-linfit)+1

#quadfit = a*t1**2 + b*t1 + c
#fnorm = (f1-quadfit)+1

# %%
plt.errorbar(t1, fnorm, yerr=fe1, fmt='o')
plt.axvline(0, c='r')

# %%
mid
# Out:
# 0.01021709106862545

# %%
ptime = ph.get_ptime(t1, mid, 29)
fnorm = np.nan_to_num(fnorm, nan=1.0)
fe1 = np.nan_to_num(fe1, nan=np.nanmedian(fe1))

# %%
#fnorm[np.argmax(fnorm)] = np.nanmedian(fnorm)

# %%
#fe1 = fe1/4

# %%
plt.errorbar(t1, fnorm, yerr=fe1, fmt='o')
plt.axvline(0, c='r')

# %%
# Inital guess: rprs, a/Rs, i, w
p0 = [0.037493, 61, 89.99, 0]

dr = 'Kepler737b'
direct = 'plots/' + dr + '/'

if not os.path.exists(direct):
    os.mkdir(direct)

# EMCEE Transit Model Fitting
_, _, rdist, adist, idist, t0dist = ph.mcmc_fitter_noper(p0, period, t1, ptime, fnorm, fe1, nwalk, nsteps_d, ndiscard_d, 'X', 'X', direct)
# Out:
#   8%|▊         | 123/1500 [00:03<00:30, 45.72it/s]Traceback (most recent call last):
#   File "/Users/ssagear/anaconda3/lib/python3.8/site-packages/emcee/ensemble.py", line 545, in __call__
#     return self.f(x, *self.args, **self.kwargs)
#   File "/Users/ssagear/Dropbox (UFL)/Research/MetallicityProject/photoeccentric/photoeccentric/photoeccentric.py", line 973, in tfit_noper_log_probability
#     return lp + tfit_noper_log_likelihood(theta, per, time, ptime, flux, flux_err)
#   File "/Users/ssagear/Dropbox (UFL)/Research/MetallicityProject/photoeccentric/photoeccentric/photoeccentric.py", line 948, in tfit_noper_log_likelihood
#     model = integratedlc_fitter(time, per, rp, a, inc, t0)
#   File "/Users/ssagear/Dropbox (UFL)/Research/MetallicityProject/photoeccentric/photoeccentric/lcfitter.py", line 164, in integratedlc_fitter
#     ptime = get_ptime(time, get_mid(time), 29)
#   File "/Users/ssagear/Dropbox (UFL)/Research/MetallicityProject/photoeccentric/photoeccentric/lcfitter.py", line 271, in get_ptime
#     ettemp = np.linspace(time[i]-mid, time[i]+mid, num, endpoint=True)
#   File "<__array_function__ internals>", line 5, in linspace
#   File "/Users/ssagear/anaconda3/lib/python3.8/site-packages/numpy/core/function_base.py", line 151, in linspace
#     y *= step
# KeyboardInterrupt
#   8%|▊         | 124/1500 [00:03<00:35, 38.74it/s]
# emcee: Exception while calling your likelihood function:
#   params: [   0.54895355  125.55668043   49.28103601 -226.9785562 ]
#   args: (28.59915399, array([-0.12571831, -0.10528542, -0.08485254, -0.06441965, -0.04398676,
#        -0.02355387, -0.00312098,  0.01731191,  0.0377448 ,  0.05817768,
#         0.07861057,  0.09904346]), array([-0.1359354 , -0.13520561, -0.13447582, -0.13374603, -0.13301623,
#        -0.13228644, -0.13155665, -0.13082686, -0.13009707, -0.12936727,
#        -0.12863748, -0.12790769, -0.1271779 , -0.12644811, -0.12571831,
#        -0.12498852, -0.12425873, -0.12352894, -0.12279914, -0.12206935,
#        -0.12133956, -0.12060977, -0.11987998, -0.11915018, -0.11842039,
#        -0.1176906 , -0.11696081, -0.11623101, -0.11550122, -0.11550252,
#        -0.11477272, -0.11404293, -0.11331314, -0.11258335, -0.11185355,
#        -0.11112376, -0.11039397, -0.10966418, -0.10893439, -0.10820459,
#        -0.1074748 , -0.10674501, -0.10601522, -0.10528542, -0.10455563,
#        -0.10382584, -0.10309605, -0.10236626, -0.10163646, -0.10090667,
#        -0.10017688, -0.09944709, -0.09871729, -0.0979875 , -0.09725771,
#        -0.09652792, -0.09579813, -0.09506833, -0.09506963, -0.09433983,
#        -0.09361004, -0.09288025, -0.09215046, -0.09142067, -0.09069087,
#        -0.08996108, -0.08923129, -0.0885015 , -0.0877717 , -0.08704191,
#        -0.08631212, -0.08558233, -0.08485254, -0.08412274, -0.08339295,
#        -0.08266316, -0.08193337, -0.08120357, -0.08047378, -0.07974399,
#        -0.0790142 , -0.07828441, -0.07755461, -0.07682482, -0.07609503,
#        -0.07536524, -0.07463544, -0.07463674, -0.07390695, -0.07317715,
#        -0.07244736, -0.07171757, -0.07098778, -0.07025798, -0.06952819,
#        -0.0687984 , -0.06806861, -0.06733882, -0.06660902, -0.06587923,
#        -0.06514944, -0.06441965, -0.06368985, -0.06296006, -0.06223027,
#        -0.06150048, -0.06077069, -0.06004089, -0.0593111 , -0.05858131,
#        -0.05785152, -0.05712172, -0.05639193, -0.05566214, -0.05493235,
#        -0.05420256, -0.05420385, -0.05347406, -0.05274426, -0.05201447,
#        -0.05128468, -0.05055489, -0.0498251 , -0.0490953 , -0.04836551,
#        -0.04763572, -0.04690593, -0.04617613, -0.04544634, -0.04471655,
#        -0.04398676, -0.04325697, -0.04252717, -0.04179738, -0.04106759,
#        -0.0403378 , -0.039608  , -0.03887821, -0.03814842, -0.03741863,
#        -0.03668884, -0.03595904, -0.03522925, -0.03449946, -0.03376967,
#        -0.03377096, -0.03304117, -0.03231138, -0.03158158, -0.03085179,
#        -0.030122  , -0.02939221, -0.02866241, -0.02793262, -0.02720283,
#        -0.02647304, -0.02574325, -0.02501345, -0.02428366, -0.02355387,
#        -0.02282408, -0.02209428, -0.02136449, -0.0206347 , -0.01990491,
#        -0.01917512, -0.01844532, -0.01771553, -0.01698574, -0.01625595,
#        -0.01552615, -0.01479636, -0.01406657, -0.01333678, -0.01333807,
#        -0.01260828, -0.01187849, -0.0111487 , -0.0104189 , -0.00968911,
#        -0.00895932, -0.00822953, -0.00749973, -0.00676994, -0.00604015,
#        -0.00531036, -0.00458057, -0.00385077, -0.00312098, -0.00239119,
#        -0.0016614 , -0.0009316 , -0.00020181,  0.00052798,  0.00125777,
#         0.00198756,  0.00271736,  0.00344715,  0.00417694,  0.00490673,
#         0.00563653,  0.00636632,  0.00709611,  0.00709482,  0.00782461,
#         0.0085544 ,  0.00928419,  0.01001399,  0.01074378,  0.01147357,
#         0.01220336,  0.01293315,  0.01366295,  0.01439274,  0.01512253,
#         0.01585232,  0.01658212,  0.01731191,  0.0180417 ,  0.01877149,
#         0.01950128,  0.02023108,  0.02096087,  0.02169066,  0.02242045,
#         0.02315025,  0.02388004,  0.02460983,  0.02533962,  0.02606941,
#         0.02679921,  0.027529  ,  0.0275277 ,  0.0282575 ,  0.02898729,
#         0.02971708,  0.03044687,  0.03117667,  0.03190646,  0.03263625,
#         0.03336604,  0.03409583,  0.03482563,  0.03555542,  0.03628521,
#         0.037015  ,  0.0377448 ,  0.03847459,  0.03920438,  0.03993417,
#         0.04066396,  0.04139376,  0.04212355,  0.04285334,  0.04358313,
#         0.04431293,  0.04504272,  0.04577251,  0.0465023 ,  0.04723209,
#         0.04796189,  0.04796059,  0.04869039,  0.04942018,  0.05014997,
#         0.05087976,  0.05160955,  0.05233935,  0.05306914,  0.05379893,
#         0.05452872,  0.05525852,  0.05598831,  0.0567181 ,  0.05744789,
#         0.05817768,  0.05890748,  0.05963727,  0.06036706,  0.06109685,
#         0.06182665,  0.06255644,  0.06328623,  0.06401602,  0.06474581,
#         0.06547561,  0.0662054 ,  0.06693519,  0.06766498,  0.06839478,
#         0.06839348,  0.06912327,  0.06985307,  0.07058286,  0.07131265,
#         0.07204244,  0.07277223,  0.07350203,  0.07423182,  0.07496161,
#         0.0756914 ,  0.0764212 ,  0.07715099,  0.07788078,  0.07861057,
#         0.07934036,  0.08007016,  0.08079995,  0.08152974,  0.08225953,
#         0.08298933,  0.08371912,  0.08444891,  0.0851787 ,  0.08590849,
#         0.08663829,  0.08736808,  0.08809787,  0.08882766,  0.08882637,
#         0.08955616,  0.09028595,  0.09101575,  0.09174554,  0.09247533,
#         0.09320512,  0.09393491,  0.09466471,  0.0953945 ,  0.09612429,
#         0.09685408,  0.09758388,  0.09831367,  0.09904346,  0.09977325,
#         0.10050304,  0.10123284,  0.10196263,  0.10269242,  0.10342221,
#         0.10415201,  0.1048818 ,  0.10561159,  0.10634138,  0.10707117,
#         0.10780097,  0.10853076,  0.10926055]), array([0.99919   , 1.00078525, 1.00101603, 1.00157678, 0.9995576 ,
#        0.99951241, 1.00014898, 0.99999388, 1.00101167, 0.99989789,
#        1.00105755, 0.9989672 ]), array([0.00067778, 0.00067794, 0.00067789, 0.00067803, 0.00067793,
#        0.00067788, 0.00067787, 0.00067787, 0.00067799, 0.00067789,
#        0.00067777, 0.0006777 ], dtype=float32))
#   kwargs: {}
#   exception:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-40-0682802bb9c8> in <module>
#       9
#      10 # EMCEE Transit Model Fitting
# ---> 11 _, _, rdist, adist, idist, t0dist = ph.mcmc_fitter_noper(p0, period, t1, ptime, fnorm, fe1, nwalk, nsteps_d, ndiscard_d, 'X', 'X', direct)
#
# ~/Dropbox (UFL)/Research/MetallicityProject/photoeccentric/photoeccentric/photoeccentric.py in mcmc_fitter_noper(guess_transit, per, time, ptime, nflux, flux_err, nwalk, nsteps, ndiscard, e, w, directory, plot_Tburnin, plot_Tcorner)
#    1031
#    1032     sampler = emcee.EnsembleSampler(nwalkers, ndim, tfit_noper_log_probability, args=(per, time, ptime, nflux, flux_err), threads=4)
# -> 1033     sampler.run_mcmc(pos, nsteps, progress=True);
#    1034     samples = sampler.get_chain()
#    1035
#
# ~/anaconda3/lib/python3.8/site-packages/emcee/ensemble.py in run_mcmc(self, initial_state, nsteps, **kwargs)
#     382
#     383         results = None
# --> 384         for results in self.sample(initial_state, iterations=nsteps, **kwargs):
#     385             pass
#     386
#
# ~/anaconda3/lib/python3.8/site-packages/emcee/ensemble.py in sample(self, initial_state, log_prob0, rstate0, blobs0, iterations, tune, skip_initial_state_check, thin_by, thin, store, progress)
#     341
#     342                     # Propose
# --> 343                     state, accepted = move.propose(model, state)
#     344                     state.random_state = self.random_state
#     345
#
# ~/anaconda3/lib/python3.8/site-packages/emcee/moves/red_blue.py in propose(self, model, state)
#      91
#      92             # Compute the lnprobs of the proposed position.
# ---> 93             new_log_probs, new_blobs = model.compute_log_prob_fn(q)
#      94
#      95             # Loop over the walkers and update them accordingly.
#
# ~/anaconda3/lib/python3.8/site-packages/emcee/ensemble.py in compute_log_prob(self, coords)
#     424             else:
#     425                 map_func = map
# --> 426             results = list(
#     427                 map_func(self.log_prob_fn, (p[i] for i in range(len(p))))
#     428             )
#
# ~/anaconda3/lib/python3.8/site-packages/emcee/ensemble.py in __call__(self, x)
#     543     def __call__(self, x):
#     544         try:
# --> 545             return self.f(x, *self.args, **self.kwargs)
#     546         except:  # pragma: no cover
#     547             import traceback
#
# ~/Dropbox (UFL)/Research/MetallicityProject/photoeccentric/photoeccentric/photoeccentric.py in tfit_noper_log_probability(theta, per, time, ptime, flux, flux_err)
#     971     if not np.isfinite(lp):
#     972         return -np.inf
# --> 973     return lp + tfit_noper_log_likelihood(theta, per, time, ptime, flux, flux_err)
#     974
#     975 ##############################################################################################
#
# ~/Dropbox (UFL)/Research/MetallicityProject/photoeccentric/photoeccentric/photoeccentric.py in tfit_noper_log_likelihood(theta, per, time, ptime, flux, flux_err)
#     946     rp, a, inc, t0 = theta
#     947
# --> 948     model = integratedlc_fitter(time, per, rp, a, inc, t0)
#     949     sigma2 = flux_err ** 2
#     950
#
# ~/Dropbox (UFL)/Research/MetallicityProject/photoeccentric/photoeccentric/lcfitter.py in integratedlc_fitter(time, per, rp, ars, inc, t0)
#     162
#     163     #times to calculate light curve
# --> 164     ptime = get_ptime(time, get_mid(time), 29)
#     165
#     166     m = batman.TransitModel(params, ptime)
#
# ~/Dropbox (UFL)/Research/MetallicityProject/photoeccentric/photoeccentric/lcfitter.py in get_ptime(time, mid, num)
#     269
#     270     for i in range(len(time)):
# --> 271         ettemp = np.linspace(time[i]-mid, time[i]+mid, num, endpoint=True)
#     272         ettemp = list(ettemp)
#     273
#
# <__array_function__ internals> in linspace(*args, **kwargs)
#
# ~/anaconda3/lib/python3.8/site-packages/numpy/core/function_base.py in linspace(start, stop, num, endpoint, retstep, dtype, axis)
#     149         else:
#     150             if _mult_inplace:
# --> 151                 y *= step
#     152             else:
#     153                 y = y * step
#
# KeyboardInterrupt:

# %%
ph.mode(rdist)
# Out:
# 0.989835250918609

# %%
ph.mode(adist)
# Out:
# 138824040095800.0

# %%
ph.mode(idist)
# Out:
# 0.9159162961717467

# %%
ph.mode(t0dist)
# Out:
# -5.653595704209818e+31

# %%
# Create a light curve with the fit parameters

mcmcfit = ph.integratedlc_fitter(t1, period, ph.mode(rdist), ph.mode(adist), ph.mode(idist), ph.mode(t0dist))
truefit = ph.integratedlc_fitter(t1, period, 0.037451, 60, 89.9, 0)

plt.errorbar(t1, fnorm, yerr=fe1, c='blue', alpha=0.5, label='Original LC', fmt="o", capsize=0)
plt.scatter(t1, mcmcfit, c='red', alpha=1.0, label='Fit LC')
plt.plot(t1, mcmcfit, c='red', alpha=1.0)
plt.plot(t1, truefit, c='green', alpha=1.0)

plt.legend()
