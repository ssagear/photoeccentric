# %% [markdown]
# ###### The probability of an eccentricity GIVEN that a planet is transiting (P(e|b)) and the probability of a longitude of periastron GIVEN that a planet is transiting (P(w|b)) are different than P(e) and P(w).

# %% [markdown]
# https://academic.oup.com/mnras/article/444/3/2263/1053015

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tqdm import tqdm
from astropy.table import Table
import astropy.units as u

# Using `batman` to create & fit fake transit
import batman

# Using astropy BLS and scipy curve_fit to fit transit
from astropy.timeseries import BoxLeastSquares
from scipy.optimize import curve_fit

import scipy.optimize as opt

# Using emcee & corner to find and plot (e, w) distribution
import emcee
import corner

# And importing `photoeccentric`
import photoeccentric as ph

# Random stuff
import scipy.constants as c
from scipy.stats import rayleigh
import os

import ECCSAMPLES
import random

# %load_ext autoreload
# %autoreload 2

# %matplotlib inline

plt.rcParams['figure.figsize'] = [12, 8]
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
nwalk = 64
nsteps_d = 3000
ndiscard_d = 1000
arrlen = (nsteps_d-ndiscard_d)*nwalk

# %%
smass_kg = 1.9885e30  # Solar mass (kg)
srad_m = 696.34e6 # Solar radius (m)

# %% [markdown]
# ## Reading in Sample Data

# %%
muirhead_data = pd.read_csv("datafiles/Muirhead2013_isochrones/muirhead_data_no_missing_data.txt", sep=" ")

# ALL Kepler planets from exo archive
planets = pd.read_csv('datafiles/exoplanetarchive/cumulative_kois.csv')

# Take the Kepler planet archive entries for the planets in Muirhead et al. 2013 sample
spectplanets = planets[planets['kepid'].isin(list(muirhead_data['KIC']))]
spectplanets = spectplanets.reset_index()

# Kepler-Gaia Data
kpgaia = Table.read('datafiles/Kepler-Gaia/kepler_dr2_4arcsec.fits', format='fits').to_pandas();

# Kepler-Gaia data for only the objects in our sample
muirhead_gaia = kpgaia[kpgaia['kepid'].isin(list(muirhead_data.KIC))]
muirhead_gaia = muirhead_gaia.reset_index()
muirhead_gaia.rename(columns={"index": "KIC"})

# Combined spectroscopy data + Gaia/Kepler data for our sample
muirhead_comb = pd.concat([muirhead_data, muirhead_gaia], axis=1)
muirhead_comb_nn = muirhead_comb[muirhead_comb.KOI.notnull()]

# Only targets from table above with published luminosities from Gaia
muirhead_comb_lums = muirhead_comb_nn[muirhead_comb_nn.lum_val.notnull()]

# Read in MESA isochrones
isochrones = pd.read_csv('datafiles/Muirhead2013_isochrones/isochrones_sdss_spitzer_lowmass.dat', sep='\s\s+', engine='python')

# %%
# Kepler ID for Kepler-1582 b
kepid = 5868793
kepname = spectplanets.loc[spectplanets['kepid'] == kepid].kepler_name.values[0]

kp1582b = muirhead_comb.loc[muirhead_comb['KIC'] == kepid]

# %%
# ph.fit_isochrone_lum() steps through all MESA isochrones and matches the ones that fit the given parameters
iso_lums = ph.fit_isochrone_lum(kp1582b, muirhead_comb, isochrones, gaia_lum=True)

# Write to csv, then read back in (keeps python notebook from crashing)
iso_lums.to_csv("datafiles/isochrones/iso_lums_" + str(kepid) + ".csv")
# Out:
# 100%|██████████| 738479/738479 [01:03<00:00, 11550.05it/s]

# %%
isodf = pd.read_csv("datafiles/isochrones/iso_lums_" + str(kepid) + ".csv")

mstar = isodf["mstar"].mean()
mstar_err = isodf["mstar"].std()

rstar = isodf["radius"].mean()
rstar_err = isodf["radius"].std()

# %%
rho_star, mass, radius = ph.find_density_dist_symmetric(mstar, mstar_err, rstar, rstar_err, arrlen)

# %%
period, period_uerr, period_lerr, rprs, rprs_uerr, rprs_lerr, _, a_uerr_arc, a_lerr_arc, i, e_arc, w_arc = ph.planet_params_from_archive(spectplanets, kepname)

# We calculate a_rs to ensure that it's consistent with the spec/Gaia stellar density.
a_rs = ph.calc_a(period*86400.0, mstar*smass_kg, rstar*srad_m)
a_rs_err = np.mean((a_uerr_arc, a_lerr_arc))

print('Stellar mass (Msun): ', mstar, 'Stellar radius (Rsun): ', rstar)
print('Period (Days): ', period, 'Rp/Rs: ', rprs)
print('a/Rs: ', a_rs)
print('i (deg): ', i)
# Out:
# Stellar mass (Msun):  0.18620280162489727 Stellar radius (Rsun):  0.21038847941706276
# Period (Days):  4.83809469 Rp/Rs:  0.036066
# a/Rs:  32.64384979582086
# i (deg):  89.98

# %%
pdist = np.random.normal(period, np.mean((abs(period_uerr), abs(period_lerr))), len(rho_star))

a_rs_gaia = ph.get_a_rs(rho_star, pdist)
a_rs_gaia_sigmin, a_rs_gaia_sigpls = ph.get_sigmas(a_rs_gaia)

a_rs_guess = np.mean(a_rs_gaia)

#a/Rs priors to put in transit fitting
a_rs_priors = [a_rs_guess-10*np.std(a_rs_gaia), a_rs_guess+10*np.std(a_rs_gaia)]

# %% [markdown]
# ### All M dwarf sample from KOI catalog

# %%
# All Kepler M DWARFS from exo archive
mdwarfs = pd.read_csv('datafiles/keplerstellar/mdwarfs_2300to3800.csv')
# Out:
# /Users/sheilasagear/opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (99) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
#mdwarfs

# %% [markdown]
# ### Assign random periods, radii to each star

# %%
# Number of planets
n=len(mdwarfs)

# %% [markdown]
# What should the min. and max. periods be?
#
# I'll put in 1 to 100 days for now. Not sure what they should be.
#
# Uniform priors (not sure about this either)

# %%
periods = np.random.uniform(low=1.0, high=100.0, size=n)
rprs = np.random.uniform(low=0.001, high=0.9, size=n)
a_rs = np.random.uniform(low=0.08, high=80.0, size=n)

# %% [markdown]
# ### Accounting for Transit Probability with Inclination

# %%
def randomInc(n):
    randNums = np.random.uniform(low=0.5, high=1, size=n)
    incs = np.arccos(2*randNums - 1)
    return incs

def i_to_b(n, a_rs):
    return a_rs*np.cos(randomInc(n))

# %% [markdown]
# The maximum value of b for a transiting planet is 1+Rp/Rs.
# At this b, the planet will just graze the edge of the star

# %%
bs = np.zeros(n)

for i in range(n):
    bs[i] = i_to_b(1, a_rs[i])

# %% [markdown]
# ### Accounting for Transit Probability with Eccentricity

# %% [markdown]
# Sample from the P(e|b) and P(w|b) priors with ECCSAMPLES:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def will_it_transit(rprs, impact):
    
    if impact <= 1 + rprs:
        return True
    elif impact > 1 + rprs:
        return False
    else:
        print(rprs)
        return np.nan

# %%
transiting = []

for i in range(n):
    transiting.append(will_it_transit(rprs[i], bs[i]))

# %%
index_lst = [i for i, val in enumerate(transiting) if val]

# %%
booleans = [transiting[i] for i in index_lst]
Tperiods = [periods[i] for i in index_lst]
Trprs = [rprs[i] for i in index_lst]

nn = len(index_lst)

# %%
# Number of samples to draw
n = int(nn)
transit = 1
verbose = 0

# Define alpha and beta
alpha = 0.867
beta = 3.030

# Generate samples
samples=[[0 for j in range(2)] for i in range(n)]
for i in tqdm(range(n)):
  xe = random.uniform(0, 1)
  xw = random.uniform(0, 1)
  ew = ECCSAMPLES.ecc_sample(transit,verbose,alpha,beta,xe,xw)
  samples[i][0] = ew[0]
  samples[i][1] = ew[1]

# Export samples
with open("ECCSAMPLES.csv", 'w') as f:
    f.writelines(','.join(str(j) for j in i) + '\n' for i in samples)
# Out:
# 100%|██████████| 25/25 [00:00<00:00, 48.45it/s]

# %%
eccdf = pd.read_csv("ECCSAMPLES.csv", header=0, names=["E", "W"])

# %%
plt.hist(eccdf['E'], bins='auto');

# %%
plt.hist(eccdf['W'], bins='auto');

# %% [markdown]
# Assuming we're equally sensitive to all periods and radii (we're not):

# %%
plt.scatter(Trprs, Tperiods)

# %% [markdown]
# The planets we actually see from Kepler will have Tperiods, and Trprs, and they will have eccdf[E] and eccdf[w]. These are for planets that transit.
#
# We won't know the e and w though. Depending on how sensitive photoeccentric is to different es and ws, we'll get a slightly different e and w distribution at the end. How do we turn that distribution into the one we we above, the true e distribution?
#
# For a certain true e, there's a probablility P(r) that it was recovered accurately.
#
# For 0.8 < e < 0.9, let's say P(r) = 0.6. I'll determine this from the sensitivity test with simluated data.

# %% [markdown]
# # All M dwarfs with planets from archive

# %%
# All Kepler M DWARFS from exo archive
mdwarfs = pd.read_csv('datafiles/exoplanetarchive/cumulative_kois.csv')

mdwarfs.drop(mdwarfs[mdwarfs['koi_steff'] > 4200].index, inplace = True)
mdwarfs.drop(mdwarfs[mdwarfs['koi_disposition'] == 'FALSE POSITIVE'].index, inplace = True)
mdwarfs.drop(mdwarfs[np.isnan(mdwarfs['koi_ror'])].index, inplace = True)

samp_rprs = np.array(mdwarfs['koi_ror'])

# %%
mdwarfs
# Out:
#          kepid kepoi_name   kepler_name koi_disposition koi_vet_stat  \
# 54    11754553  K00775.01   Kepler-52 c       CONFIRMED         Done
# 55    11754553  K00775.02   Kepler-52 b       CONFIRMED         Done
# 56    11754553  K00775.03   Kepler-52 d       CONFIRMED         Done
# 59    11853255  K00778.01  Kepler-674 b       CONFIRMED         Done
# 64    11923270  K00781.01  Kepler-676 b       CONFIRMED         Done
# ...        ...        ...           ...             ...          ...
# 9148   8423344  K07592.01           NaN       CANDIDATE         Done
# 9229   5858919  K08109.01           NaN       CANDIDATE         Done
# 9240  10403228  K08007.01           NaN       CANDIDATE         Done
# 9259  10452252  K08012.01           NaN       CANDIDATE         Done
# 9329  10920281  K08037.01           NaN       CANDIDATE         Done
#
#      koi_vet_date koi_pdisposition  koi_score  koi_fpflag_nt  koi_fpflag_ss  \
# ...

# %%
# Number of planets
n=len(mdwarfs)

# %%
periods = np.array(mdwarfs['koi_period'])
rprs = np.array(mdwarfs['koi_ror'])

# %% [markdown]
# ### Accounting for Transit Probability with Eccentricity

# %% [markdown]
# Sample from the P(e|b) and P(w|b) priors with ECCSAMPLES:

# %%
transiting = []

for i in range(n):
    transiting.append(will_it_transit(rprs[i], bs[i]))

# %%
index_lst = [i for i, val in enumerate(transiting) if val]

# %%
booleans = [transiting[i] for i in index_lst]
Tperiods = [periods[i] for i in index_lst]
Trprs = [rprs[i] for i in index_lst]

nn = len(index_lst)

# %%
# Number of samples to draw
n = int(nn)
transit = 1
verbose = 0

# Define alpha and beta
alpha = 0.867
beta = 3.030

# Generate samples
samples=[[0 for j in range(2)] for i in range(n)]
for i in tqdm(range(n)):
  xe = random.uniform(0, 1)
  xw = random.uniform(0, 1)
  ew = ECCSAMPLES.ecc_sample(transit,verbose,alpha,beta,xe,xw)
  samples[i][0] = ew[0]
  samples[i][1] = ew[1]

# Export samples
with open("ECCSAMPLES.csv", 'w') as f:
    f.writelines(','.join(str(j) for j in i) + '\n' for i in samples)
# Out:
# 100%|██████████| 21/21 [00:00<00:00, 66.16it/s]

# %%
eccdf = pd.read_csv("ECCSAMPLES.csv", header=0, names=["E", "W"])

# %%
plt.hist(eccdf['E'], bins='auto');

# %%
plt.hist(eccdf['W'], bins='auto');

# %% [markdown]
# Assuming we're equally sensitive to all periods and radii (we're not):

# %%
plt.scatter(Trprs, Tperiods)
